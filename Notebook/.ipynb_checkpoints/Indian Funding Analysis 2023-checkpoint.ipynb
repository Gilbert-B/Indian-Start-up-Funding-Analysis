# %% [markdown]
# <a href="https://colab.research.google.com/github/eaedk/Machine-Learning-Tutorials/blob/main/DataAnalysis_Step_By_Step_Guide.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Intro
# ## General
#
#
#
# "Exploratory Data Analysis (EDA) refers to the critical process of performing initial investigations on data so as to discover patterns,to spot anomalies,to test hypothesis and to check assumptions with the help of summary statistics and graphical representations."(https://towardsdatascience.com/exploratory-data-analysis)
#
# EDA enables us ask meaningful questions and gain insights on factors that can impact our business.It also aids by informing conclusions and supporting decision making.
#
# In Data Analysis, there are some analysis paradigms : **Univariate, Bivariate, Multivariate**. We apply these paradigms to analyze the features (or statistical variables, or columns of the dataframe) of the dataset and to have a better understanding.
#
# **Numeric features** are features with numbers that you can perform mathematical operations on. They are further divided into discrete (countable integers with clear boundaries) and continuous (can take any value, even decimals, within a range).
#
# **Categorical features** are columns with a limited number of possible values. Examples are `sex, country, or age group`.
#
# ## Notebook overview
#
# This notebook seeks to document the process undertaken to analyze fundings received by Indian Start-ups from 2018 to 2021.

# %% [markdown]
# # Setup

# %% [markdown]
# ## Installation
# Here is the section to install all the packages/libraries that will be needed to tackle the challlenge.

# %%
# pip install pandas
# pip install numpy 
# pip install matplotlib
# pip install seaborn 
# pip install forex_python
# pip install babel 
# pip install seaborn

# %% [markdown]
# ## Importation
# Here is the section to import all the packages/libraries that will be used through this notebook.

# %%
# Data handling
import pandas as pd
import numpy as np
from statistics import mean
from forex_python.converter import CurrencyRates
from babel.numbers import format_currency
import datetime as dt

# Vizualisation (Matplotlib, Plotly, Seaborn, etc. )
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sn

# %% [markdown]
# # Data Loading
# Here is the section to load the datasets (train, eval, test) and the additional files

# %%
df2018 = pd.read_csv(r"C:\Users\GilB\OneDrive\Documents\Azubi\Projetcs\Indian Startup Funding\startup_funding2018.csv")
df2019 = pd.read_csv(r"C:\Users\GilB\OneDrive\Documents\Azubi\Projetcs\Indian Startup Funding\startup_funding2019.csv")
df2020 = pd.read_csv(r"C:\Users\GilB\OneDrive\Documents\Azubi\Projetcs\Indian Startup Funding\startup_funding2020.csv")
df2021 = pd.read_csv(r"C:\Users\GilB\OneDrive\Documents\Azubi\Projetcs\Indian Startup Funding\startup_funding2021.csv")

# %% [markdown]
# # Exploratory Data Analysis: EDA
# Here is the section to **inspect** the datasets in depth, **present** it, make **hypotheses** and **think** the *cleaning, processing and features creation*.

# %% [markdown]
# ## Dataset overview
#
# Have a look at the loaded datsets using the following methods: `.head(), .info()`

# %%
# A quick look at the shape of our dataset

df2018.shape
# Out:
# (526, 6)

# %%
#Taking a look at the head of our 2018 Data

df2018.head()
# Out:
#       Company Name                                           Industry  \
# 0  TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1  Happy Cow Dairy                               Agriculture, Farming
# 2       MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3      PayMe India                        Financial Services, FinTech
# 4         Eunimart                 E-Commerce Platforms, Retail, SaaS
#
#   Round/Series       Amount                          Location  \
# 0         Seed       250000       Bangalore, Karnataka, India
# 1         Seed  ₹40,000,000        Mumbai, Maharashtra, India
# 2     Series A  ₹65,000,000           Gurgaon, Haryana, India
# 3        Angel      2000000       Noida, Uttar Pradesh, India
# 4         Seed            —  Hyderabad, Andhra Pradesh, India
#
#                                        About Company
# 0  TheCollegeFever is a hub for fun, fiesta and f...
# 1  A startup which aggregates milk from dairy far...
# 2          Leading Online Loans Marketplace in India
# 3  PayMe India is an innovative FinTech organizat...
# 4  Eunimart is a one stop solution for merchants ...

# %%
#Taking a look at the tail of our 2018 Data

df2018.tail()
# Out:
#           Company Name                                          Industry  \
# 521              Udaan  B2B, Business Development, Internet, Marketplace
# 522  Happyeasygo Group                                   Tourism, Travel
# 523             Mombay        Food and Beverage, Food Delivery, Internet
# 524         Droni Tech                            Information Technology
# 525            Netmeds        Biotechnology, Health Care, Pharmaceutical
#
#     Round/Series       Amount                     Location  \
# 521     Series C    225000000  Bangalore, Karnataka, India
# 522     Series A            —      Haryana, Haryana, India
# 523         Seed         7500   Mumbai, Maharashtra, India
# 524         Seed  ₹35,000,000   Mumbai, Maharashtra, India
# 525     Series C     35000000   Chennai, Tamil Nadu, India
#
#                                          About Company
# 521  Udaan is a B2B trade platform, designed specif...
# 522            HappyEasyGo is an online travel domain.
# 523  Mombay is a unique opportunity for housewives ...
# 524  Droni Tech manufacture UAVs and develop softwa...
# 525       Welcome to India's most convenient pharmacy!

# %%
#Look at the columns in the dataset and their data types

df2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 526 entries, 0 to 525
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company Name   526 non-null    object
#  1   Industry       526 non-null    object
#  2   Round/Series   526 non-null    object
#  3   Amount         526 non-null    object
#  4   Location       526 non-null    object
#  5   About Company  526 non-null    object
# dtypes: object(6)
# memory usage: 24.8+ KB

# %%
# A quick look at the shape of our dataset

df2019.shape
# Out:
# (89, 9)

# %%
#Taking a look at the head of our 2021 Data

df2019.head()
# Out:
#     Company/Brand  Founded HeadQuarter           Sector  \
# 0  Bombay Shaving      NaN         NaN        Ecommerce
# 1       Ruangguru   2014.0      Mumbai           Edtech
# 2        Eduisfun      NaN      Mumbai           Edtech
# 3        HomeLane   2014.0     Chennai  Interior design
# 4        Nu Genes   2004.0   Telangana         AgriTech
#
#                                         What it does  \
# 0         Provides a range of male grooming products
# 1  A learning platform that provides topic-based ...
# 2            It aims to make learning fun via games.
# 3              Provides interior designing solutions
# 4  It is a seed company engaged in production, pr...
#
#                                 Founders  \
# 0                     Shantanu Deshpande
# 1  Adamas Belva Syah Devara, Iman Usman.
# 2                          Jatin Solanki
# 3           Srikanth Iyer, Rama Harinath
# 4                 Narayana Reddy Punyala
#
#                                             Investor     Amount($)  \
# 0                               Sixth Sense Ventures    $6,300,000
# 1                                   General Atlantic  $150,000,000
# 2     Deepak Parekh, Amitabh Bachchan, Piyush Pandey   $28,000,000
# 3  Evolvence India Fund (EIF), Pidilite Group, FJ...   $30,000,000
# 4           Innovation in Food and Agriculture (IFA)    $6,000,000
#
#            Stage
# 0            NaN
# 1       Series C
# 2  Fresh funding
# 3       Series D
# 4            NaN

# %%
#Taking a look at the tail of our 2021 Data

df2019.tail()
# Out:
#       Company/Brand  Founded HeadQuarter                   Sector  \
# 84     Infra.Market      NaN      Mumbai                Infratech
# 85              Oyo   2013.0    Gurugram              Hospitality
# 86       GoMechanic   2016.0       Delhi  Automobile & Technology
# 87           Spinny   2015.0       Delhi               Automobile
# 88  Ess Kay Fincorp      NaN   Rajasthan                  Banking
#
#                                          What it does  \
# 84  It connects client requirements to their suppl...
# 85                Provides rooms for comfortable stay
# 86  Find automobile repair and maintenance service...
# 87                                Online car retailer
# 88              Organised Non-Banking Finance Company
#
#                                              Founders  \
# 84                    Aaditya Sharda, Souvik Sengupta
# 85                                     Ritesh Agarwal
# 86  Amit Bhasin, Kushal Karwa, Nitin Rana, Rishabh...
# 87  Niraj Singh, Ramanshu Mahaur, Ganesh Pawar, Mo...
# 88                                     Rajendra Setia
#
#                                              Investor     Amount($)     Stage
# 84  Tiger Global, Nexus Venture Partners, Accel Pa...   $20,000,000  Series A
# 85  MyPreferred Transformation, Avendus Finance, S...  $693,000,000       NaN
# 86                                    Sequoia Capital    $5,000,000  Series B
# 87  Norwest Venture Partners, General Catalyst, Fu...   $50,000,000       NaN
# 88     TPG, Norwest Venture Partners, Evolvence India   $33,000,000       NaN

# %%
#Look at the columns in the dataset and their data types

df2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  89 non-null     object
#  1   Founded        60 non-null     float64
#  2   HeadQuarter    70 non-null     object
#  3   Sector         84 non-null     object
#  4   What it does   89 non-null     object
#  5   Founders       86 non-null     object
#  6   Investor       89 non-null     object
#  7   Amount($)      89 non-null     object
#  8   Stage          43 non-null     object
# dtypes: float64(1), object(8)
# memory usage: 6.4+ KB

# %%
# A quick look at the shape of our dataset

df2020.shape
# Out:
# (1055, 10)

# %%
#Taking a look at the head of our 2021 Data

df2020.head()
# Out:
#   Company/Brand Founded HeadQuarter              Sector  \
# 0    Aqgromalin    2019     Chennai            AgriTech
# 1      Krayonnz    2019   Bangalore              EdTech
# 2  PadCare Labs    2018        Pune  Hygiene management
# 3         NCOME    2020   New Delhi              Escrow
# 4    Gramophone    2016      Indore            AgriTech
#
#                                         What it does  \
# 0                       Cultivating Ideas for Profit
# 1  An academy-guardian-scholar centric ecosystem ...
# 2   Converting bio-hazardous waste to harmless waste
# 3                       Escrow-as-a-service platform
# 4  Gramophone is an AgTech platform enabling acce...
#
#                                             Founders  \
# 0                    Prasanna Manogaran, Bharani C L
# 1                   Saurabh Dixit, Gurudutt Upadhyay
# 2                                    Ajinkya Dhariya
# 3                                      Ritesh Tiwari
# 4  Ashish Rajan Singh, Harshit Gupta, Nishant Mah...
#
#                               Investor    Amount($)     Stage Unnamed: 9
# 0                      Angel investors     $200,000       NaN        NaN
# 1                      GSF Accelerator     $100,000  Pre-seed        NaN
# 2                       Venture Center  Undisclosed  Pre-seed        NaN
# 3  Venture Catalysts, PointOne Capital     $400,000       NaN        NaN
# 4  Siana Capital Management, Info Edge     $340,000       NaN        NaN

# %%
#Taking a look at the tail of our 2021 Data

df2020.tail()
# Out:
#      Company/Brand Founded HeadQuarter     Sector  \
# 1050  Leverage Edu     NaN       Delhi     Edtech
# 1051         EpiFi     NaN         NaN    Fintech
# 1052       Purplle    2012      Mumbai  Cosmetics
# 1053        Shuttl    2015       Delhi  Transport
# 1054         Pando    2017     Chennai   Logitech
#
#                                            What it does  \
# 1050  AI enabled marketplace that provides career gu...
# 1051  It offers customers with a single interface fo...
# 1052         Online makeup and beauty products retailer
# 1053                    App based bus aggregator serice
# 1054            Networked logistics management software
#
#                              Founders                               Investor  \
# 1050                Akshay Chaturvedi  DSG Consumer Partners, Blume Ventures
# 1051  Sujith Narayanan, Sumit Gwalani          Sequoia India, Ribbit Capital
# 1052        Manish Taneja, Rahul Dash                             Verlinvest
# 1053    Amit Singh, Deepanshu Malviya             SIG Global India Fund LLP.
# 1054   Jayakrishnan, Abhijeet Manohar                      Chiratae Ventures
#
#         Amount($)       Stage Unnamed: 9
# 1050   $1,500,000         NaN        NaN
# 1051  $13,200,000  Seed Round        NaN
# 1052   $8,000,000         NaN        NaN
# 1053   $8,043,000    Series C        NaN
# 1054   $9,000,000    Series A        NaN

# %%
#Look at the columns in the dataset and their data types

df2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1055 entries, 0 to 1054
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  1055 non-null   object
#  1   Founded        843 non-null    object
#  2   HeadQuarter    961 non-null    object
#  3   Sector         1042 non-null   object
#  4   What it does   1055 non-null   object
#  5   Founders       1043 non-null   object
#  6   Investor       1017 non-null   object
#  7   Amount($)      1052 non-null   object
#  8   Stage          591 non-null    object
#  9   Unnamed: 9     2 non-null      object
# dtypes: object(10)
# memory usage: 82.5+ KB

# %%
# A quick look at the shape of our dataset

df2021.shape
# Out:
# (1209, 9)

# %%
#Taking a look at the head of our 2021 Data

df2021.head()
# Out:
#     Company/Brand  Founded HeadQuarter          Sector  \
# 0  Unbox Robotics   2019.0   Bangalore      AI startup
# 1          upGrad   2015.0      Mumbai          EdTech
# 2     Lead School   2012.0      Mumbai          EdTech
# 3         Bizongo   2015.0      Mumbai  B2B E-commerce
# 4        FypMoney   2021.0    Gurugram         FinTech
#
#                                         What it does  \
# 0  Unbox Robotics builds on-demand AI-driven ware...
# 1     UpGrad is an online higher education platform.
# 2  LEAD School offers technology based school tra...
# 3  Bizongo is a business-to-business online marke...
# 4  FypMoney is Digital NEO Bank for Teenagers, em...
#
#                                             Founders  \
# 0                        Pramod Ghadge, Shahid Memon
# 1  Mayank Kumar, Phalgun Kompalli, Ravijot Chugh,...
# 2                         Smita Deorah, Sumeet Mehta
# 3            Aniket Deb, Ankit Tomar, Sachin Agrawal
# 4                                      Kapil Banwari
#
#                                         Investor     Amount($)         Stage
# 0                    BEENEXT, Entrepreneur First    $1,200,000  Pre-series A
# 1       Unilazer Ventures, IIFL Asset Management  $120,000,000           NaN
# 2               GSV Ventures, Westbridge Capital   $30,000,000      Series D
# 3                         CDC Group, IDG Capital   $51,000,000      Series C
# 4  Liberatha Kallat, Mukesh Yadav, Dinesh Nagpal    $2,000,000          Seed

# %%
#Taking a look at the tail of our 2021 Data

df2021.tail()
# Out:
#      Company/Brand  Founded HeadQuarter                 Sector  \
# 1204      Gigforce   2019.0    Gurugram  Staffing & Recruiting
# 1205        Vahdam   2015.0   New Delhi       Food & Beverages
# 1206  Leap Finance   2019.0   Bangalore     Financial Services
# 1207  CollegeDekho   2015.0    Gurugram                 EdTech
# 1208        WeRize   2019.0   Bangalore     Financial Services
#
#                                            What it does  \
# 1204                  A gig/on-demand staffing company.
# 1205  VAHDAM is among the world’s first vertically i...
# 1206  International education loans for high potenti...
# 1207  Collegedekho.com is Student’s Partner, Friend ...
# 1208  India’s first socially distributed full stack ...
#
#                            Founders                          Investor  \
# 1204    Chirag Mittal, Anirudh Syal                   Endiya Partners
# 1205                     Bala Sarda                          IIFL AMC
# 1206     Arnav Kumar, Vaibhav Singh                      Owl Ventures
# 1207                   Ruchir Arora  Winter Capital, ETS, Man Capital
# 1208  Vishal Chopra, Himanshu Gupta    3one4 Capital, Kalaari Capital
#
#       Amount($)         Stage
# 1204   $3000000  Pre-series A
# 1205  $20000000      Series D
# 1206  $55000000      Series C
# 1207  $26000000      Series B
# 1208   $8000000      Series A

# %%
#Look at the columns in the dataset and their data types

df2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1209 entries, 0 to 1208
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  1209 non-null   object
#  1   Founded        1208 non-null   float64
#  2   HeadQuarter    1208 non-null   object
#  3   Sector         1209 non-null   object
#  4   What it does   1209 non-null   object
#  5   Founders       1205 non-null   object
#  6   Investor       1147 non-null   object
#  7   Amount($)      1206 non-null   object
#  8   Stage          781 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 85.1+ KB

# %% [markdown]
# ###  Questions

# %% [markdown]
# 1. Which company received the highest amount of funds?
#
# 2. Which company received the lowest amount of funds ?
#
# 3. Which Industry received the highest amount of funding?
#
# 4. Which Industry received the lowest amount of funding?
#
# 5. Is there a correlation between company age and funds received?
#
# 6. Which location recorded the highest amount of funding received?
#
# 7. What is the average age of the start-ups?
#
# 8. What is the average amount of funding received each year?
#
# 9. How many companies were funded in each year?

# %% [markdown]
# ### Hypothesis

# %% [markdown]
# Null Hypothesis - The sector of a start-up affect the amount of funding received.
#
# Alternate Hypothesis - The sector of a start up does not affect the amount of funding received

# %% [markdown]
# ## Issues With The Data

# %% [markdown]
# After looking carefully at the data, the following issues were identified
#
# 1. The 2018 Dataset had different and fewer columns
# 2. The data sets have missing values
# 3. Some values are in the wrong columns
# 4. The datatypes of some of the columns need to be changed
# 5. One column is unnamed

# %% [markdown]
# ## How To Handle Issues

# %% [markdown]
# 1. Analyze the 2018 data separately of the rest
# 2. Replace missing data with either N/A or the mode of that column depeding on the column data
# 3. Move values in the wrong columns to their appropriate columns
# 4. Change datatype of columns to appropriate datatypes
# 5. Rename columns

# %% [markdown]
# ## Data Preparation
#
# A careful look at the data shows that df2018 is different from all the other data sets.
# We will combine df2019,df2020 and df2021.
#
# df2018 will cleaned and analyzed separately

# %%
#We observe that ithere are dashes in the Amount column. We will replace the dashes(—) with 0
df2018['Amount'] == '—'
df2018[df2018.columns[3: ]] = df2018[df2018.columns[3: ]].replace('[\—,]' , '0' , regex=True)
df2018
# Out:
#           Company Name                                           Industry  \
# 0      TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1      Happy Cow Dairy                               Agriculture, Farming
# 2           MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3          PayMe India                        Financial Services, FinTech
# 4             Eunimart                 E-Commerce Platforms, Retail, SaaS
# ..                 ...                                                ...
# 521              Udaan   B2B, Business Development, Internet, Marketplace
# 522  Happyeasygo Group                                    Tourism, Travel
# 523             Mombay         Food and Beverage, Food Delivery, Internet
# 524         Droni Tech                             Information Technology
# 525            Netmeds         Biotechnology, Health Care, Pharmaceutical
#
#     Round/Series       Amount                          Location  \
# 0           Seed       250000       Bangalore0 Karnataka0 India
# 1           Seed  ₹4000000000        Mumbai0 Maharashtra0 India
# 2       Series A  ₹6500000000           Gurgaon0 Haryana0 India
# 3          Angel      2000000       Noida0 Uttar Pradesh0 India
# 4           Seed            0  Hyderabad0 Andhra Pradesh0 India
# ..           ...          ...                               ...
# 521     Series C    225000000       Bangalore0 Karnataka0 India
# 522     Series A            0           Haryana0 Haryana0 India
# 523         Seed         7500        Mumbai0 Maharashtra0 India
# 524         Seed  ₹3500000000        Mumbai0 Maharashtra0 India
# 525     Series C     35000000        Chennai0 Tamil Nadu0 India
#
#                                          About Company
# 0    TheCollegeFever is a hub for fun0 fiesta and f...
# 1    A startup which aggregates milk from dairy far...
# 2            Leading Online Loans Marketplace in India
# 3    PayMe India is an innovative FinTech organizat...
# 4    Eunimart is a one stop solution for merchants ...
# ..                                                 ...
# 521  Udaan is a B2B trade platform0 designed specif...
# 522            HappyEasyGo is an online travel domain.
# 523  Mombay is a unique opportunity for housewives ...
# 524  Droni Tech manufacture UAVs and develop softwa...
# 525       Welcome to India's most convenient pharmacy!
#
# [526 rows x 6 columns]

# %%
#To differentiate the various currencies in our data set,a new column for currency and date is created 
df2018['Currency'] = np.where(df2018.Amount.str.contains('₹'), 'INR', 'USD')
df2018['Currency_Rate_Date'] = dt.datetime(2018,12,31)
df2018.head(350)
# Out:
#                                        Company Name  \
# 0                                   TheCollegeFever
# 1                                   Happy Cow Dairy
# 2                                        MyLoanCare
# 3                                       PayMe India
# 4                                          Eunimart
# ..                                              ...
# 345                                      FreightBro
# 346                                         Finwego
# 347                                        Cricnwin
# 348                                 TheCollegeFever
# 349  Wicked Ride Adventure Services Private Limited
#
#                                               Industry  \
# 0    Brand Marketing, Event Promotion, Marketing, S...
# 1                                 Agriculture, Farming
# 2     Credit, Financial Services, Lending, Marketplace
# 3                          Financial Services, FinTech
# 4                   E-Commerce Platforms, Retail, SaaS
# ..                                                 ...
# 345  Apps, B2B, Freight Service, Logistics, SaaS, S...
# 346                                                  —
# 347  Digital Entertainment, Fantasy Sports, Gaming,...
# 348  Brand Marketing, Event Promotion, Marketing, S...
# 349  Automotive, Last Mile Transportation, Peer to ...
#
#                  Round/Series       Amount                          Location  \
# 0                        Seed       250000       Bangalore0 Karnataka0 India
# 1                        Seed  ₹4000000000        Mumbai0 Maharashtra0 India
# 2                    Series A  ₹6500000000           Gurgaon0 Haryana0 India
# 3                       Angel      2000000       Noida0 Uttar Pradesh0 India
# 4                        Seed            0  Hyderabad0 Andhra Pradesh0 India
# ..                        ...          ...                               ...
# 345                      Seed            0        Mumbai0 Maharashtra0 India
# 346                      Seed            0        Chennai0 Tamil Nadu0 India
# 347                      Seed            0           Gurgaon0 Haryana0 India
# 348                      Seed       250000       Bangalore0 Karnataka0 India
# 349  Venture - Series Unknown  $1000000000       Bangalore0 Karnataka0 India
#
#                                          About Company Currency  \
# 0    TheCollegeFever is a hub for fun0 fiesta and f...      USD
# 1    A startup which aggregates milk from dairy far...      INR
# 2            Leading Online Loans Marketplace in India      INR
# 3    PayMe India is an innovative FinTech organizat...      USD
# 4    Eunimart is a one stop solution for merchants ...      USD
# ..                                                 ...      ...
# 345                   Software for the new-age freight      USD
# 346  Finwego partners with Small and Medium Busines...      USD
# 347  Cricnwin is a Gurugram - based Fan Engagement ...      USD
# 348  TheCollegeFever is a hub for fun0 fiesta and f...      USD
# 349                Peer-to-Peer motor vehicles sharing      USD
#
#     Currency_Rate_Date
# 0           2018-12-31
# 1           2018-12-31
# 2           2018-12-31
# 3           2018-12-31
# 4           2018-12-31
# ..                 ...
# 345         2018-12-31
# 346         2018-12-31
# 347         2018-12-31
# 348         2018-12-31
# 349         2018-12-31
#
# [350 rows x 8 columns]

# %%
#All currency symbols in our column is removed and the amcount is converted into a float
df2018['Amount'] = df2018['Amount'].replace({'\$': '', '\₹': ''}, regex=True).astype(float)
df2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 526 entries, 0 to 525
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Company Name        526 non-null    object
#  1   Industry            526 non-null    object
#  2   Round/Series        526 non-null    object
#  3   Amount              526 non-null    float64
#  4   Location            526 non-null    object
#  5   About Company       526 non-null    object
#  6   Currency            526 non-null    object
#  7   Currency_Rate_Date  526 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(6)
# memory usage: 33.0+ KB

# %%
df2018
# Out:
#           Company Name                                           Industry  \
# 0      TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1      Happy Cow Dairy                               Agriculture, Farming
# 2           MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3          PayMe India                        Financial Services, FinTech
# 4             Eunimart                 E-Commerce Platforms, Retail, SaaS
# ..                 ...                                                ...
# 521              Udaan   B2B, Business Development, Internet, Marketplace
# 522  Happyeasygo Group                                    Tourism, Travel
# 523             Mombay         Food and Beverage, Food Delivery, Internet
# 524         Droni Tech                             Information Technology
# 525            Netmeds         Biotechnology, Health Care, Pharmaceutical
#
#     Round/Series        Amount                          Location  \
# 0           Seed  2.500000e+05       Bangalore0 Karnataka0 India
# 1           Seed  4.000000e+09        Mumbai0 Maharashtra0 India
# 2       Series A  6.500000e+09           Gurgaon0 Haryana0 India
# 3          Angel  2.000000e+06       Noida0 Uttar Pradesh0 India
# 4           Seed  0.000000e+00  Hyderabad0 Andhra Pradesh0 India
# ..           ...           ...                               ...
# 521     Series C  2.250000e+08       Bangalore0 Karnataka0 India
# 522     Series A  0.000000e+00           Haryana0 Haryana0 India
# 523         Seed  7.500000e+03        Mumbai0 Maharashtra0 India
# 524         Seed  3.500000e+09        Mumbai0 Maharashtra0 India
# 525     Series C  3.500000e+07        Chennai0 Tamil Nadu0 India
#
#                                          About Company Currency  \
# 0    TheCollegeFever is a hub for fun0 fiesta and f...      USD
# 1    A startup which aggregates milk from dairy far...      INR
# 2            Leading Online Loans Marketplace in India      INR
# 3    PayMe India is an innovative FinTech organizat...      USD
# 4    Eunimart is a one stop solution for merchants ...      USD
# ..                                                 ...      ...
# 521  Udaan is a B2B trade platform0 designed specif...      USD
# 522            HappyEasyGo is an online travel domain.      USD
# 523  Mombay is a unique opportunity for housewives ...      USD
# 524  Droni Tech manufacture UAVs and develop softwa...      INR
# 525       Welcome to India's most convenient pharmacy!      USD
#
#     Currency_Rate_Date
# 0           2018-12-31
# 1           2018-12-31
# 2           2018-12-31
# 3           2018-12-31
# 4           2018-12-31
# ..                 ...
# 521         2018-12-31
# 522         2018-12-31
# 523         2018-12-31
# 524         2018-12-31
# 525         2018-12-31
#
# [526 rows x 8 columns]

# %%
#Converting Amount to same currency

c = CurrencyRates()
df2018['Amount_USD'] = df2018.apply(lambda x: c.convert(x.Currency, 'USD', x.Amount, x.Currency_Rate_Date), axis = 1)
exchange_rate = c.get_rate('USD','INR')


df2018.head(350)
# Out:
#                                        Company Name  \
# 0                                   TheCollegeFever
# 1                                   Happy Cow Dairy
# 2                                        MyLoanCare
# 3                                       PayMe India
# 4                                          Eunimart
# ..                                              ...
# 345                                      FreightBro
# 346                                         Finwego
# 347                                        Cricnwin
# 348                                 TheCollegeFever
# 349  Wicked Ride Adventure Services Private Limited
#
#                                               Industry  \
# 0    Brand Marketing, Event Promotion, Marketing, S...
# 1                                 Agriculture, Farming
# 2     Credit, Financial Services, Lending, Marketplace
# 3                          Financial Services, FinTech
# 4                   E-Commerce Platforms, Retail, SaaS
# ..                                                 ...
# 345  Apps, B2B, Freight Service, Logistics, SaaS, S...
# 346                                                  —
# 347  Digital Entertainment, Fantasy Sports, Gaming,...
# 348  Brand Marketing, Event Promotion, Marketing, S...
# 349  Automotive, Last Mile Transportation, Peer to ...
#
#                  Round/Series        Amount                          Location  \
# 0                        Seed  2.500000e+05       Bangalore0 Karnataka0 India
# 1                        Seed  4.000000e+09        Mumbai0 Maharashtra0 India
# 2                    Series A  6.500000e+09           Gurgaon0 Haryana0 India
# 3                       Angel  2.000000e+06       Noida0 Uttar Pradesh0 India
# 4                        Seed  0.000000e+00  Hyderabad0 Andhra Pradesh0 India
# ..                        ...           ...                               ...
# 345                      Seed  0.000000e+00        Mumbai0 Maharashtra0 India
# 346                      Seed  0.000000e+00        Chennai0 Tamil Nadu0 India
# 347                      Seed  0.000000e+00           Gurgaon0 Haryana0 India
# 348                      Seed  2.500000e+05       Bangalore0 Karnataka0 India
# 349  Venture - Series Unknown  1.000000e+09       Bangalore0 Karnataka0 India
#
#                                          About Company Currency  \
# 0    TheCollegeFever is a hub for fun0 fiesta and f...      USD
# 1    A startup which aggregates milk from dairy far...      INR
# 2            Leading Online Loans Marketplace in India      INR
# 3    PayMe India is an innovative FinTech organizat...      USD
# 4    Eunimart is a one stop solution for merchants ...      USD
# ..                                                 ...      ...
# 345                   Software for the new-age freight      USD
# 346  Finwego partners with Small and Medium Busines...      USD
# 347  Cricnwin is a Gurugram - based Fan Engagement ...      USD
# 348  TheCollegeFever is a hub for fun0 fiesta and f...      USD
# 349                Peer-to-Peer motor vehicles sharing      USD
#
#     Currency_Rate_Date    Amount_USD
# 0           2018-12-31  2.500000e+05
# 1           2018-12-31  5.744402e+07
# 2           2018-12-31  9.334653e+07
# 3           2018-12-31  2.000000e+06
# 4           2018-12-31  0.000000e+00
# ..                 ...           ...
# 345         2018-12-31  0.000000e+00
# 346         2018-12-31  0.000000e+00
# 347         2018-12-31  0.000000e+00
# 348         2018-12-31  2.500000e+05
# 349         2018-12-31  1.000000e+09
#
# [350 rows x 9 columns]

# %%
#Changing how floats look like in our data. We change to 2 decimal places 
pd.options.display.float_format = '{:.2f}'.format

# %%
df2018
# Out:
#           Company Name                                           Industry  \
# 0      TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1      Happy Cow Dairy                               Agriculture, Farming
# 2           MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3          PayMe India                        Financial Services, FinTech
# 4             Eunimart                 E-Commerce Platforms, Retail, SaaS
# ..                 ...                                                ...
# 521              Udaan   B2B, Business Development, Internet, Marketplace
# 522  Happyeasygo Group                                    Tourism, Travel
# 523             Mombay         Food and Beverage, Food Delivery, Internet
# 524         Droni Tech                             Information Technology
# 525            Netmeds         Biotechnology, Health Care, Pharmaceutical
#
#     Round/Series        Amount                          Location  \
# 0           Seed     250000.00       Bangalore0 Karnataka0 India
# 1           Seed 4000000000.00        Mumbai0 Maharashtra0 India
# 2       Series A 6500000000.00           Gurgaon0 Haryana0 India
# 3          Angel    2000000.00       Noida0 Uttar Pradesh0 India
# 4           Seed          0.00  Hyderabad0 Andhra Pradesh0 India
# ..           ...           ...                               ...
# 521     Series C  225000000.00       Bangalore0 Karnataka0 India
# 522     Series A          0.00           Haryana0 Haryana0 India
# 523         Seed       7500.00        Mumbai0 Maharashtra0 India
# 524         Seed 3500000000.00        Mumbai0 Maharashtra0 India
# 525     Series C   35000000.00        Chennai0 Tamil Nadu0 India
#
#                                          About Company Currency  \
# 0    TheCollegeFever is a hub for fun0 fiesta and f...      USD
# 1    A startup which aggregates milk from dairy far...      INR
# 2            Leading Online Loans Marketplace in India      INR
# 3    PayMe India is an innovative FinTech organizat...      USD
# 4    Eunimart is a one stop solution for merchants ...      USD
# ..                                                 ...      ...
# 521  Udaan is a B2B trade platform0 designed specif...      USD
# 522            HappyEasyGo is an online travel domain.      USD
# 523  Mombay is a unique opportunity for housewives ...      USD
# 524  Droni Tech manufacture UAVs and develop softwa...      INR
# 525       Welcome to India's most convenient pharmacy!      USD
#
#     Currency_Rate_Date   Amount_USD
# 0           2018-12-31    250000.00
# 1           2018-12-31  57444017.17
# 2           2018-12-31  93346527.90
# 3           2018-12-31   2000000.00
# 4           2018-12-31         0.00
# ..                 ...          ...
# 521         2018-12-31 225000000.00
# 522         2018-12-31         0.00
# 523         2018-12-31      7500.00
# 524         2018-12-31  50263515.02
# 525         2018-12-31  35000000.00
#
# [526 rows x 9 columns]

# %% [markdown]
# #### Cleaning df2019, df2020 and df2021

# %%
#Combing all 3 data sets into a single data frame (DF)

frames = [df2019, df2020, df2021]
  
df= pd.concat(frames)

# %%
df
# Out:
#        Company/Brand Founded HeadQuarter                 Sector  \
# 0     Bombay Shaving     NaN         NaN              Ecommerce
# 1          Ruangguru 2014.00      Mumbai                 Edtech
# 2           Eduisfun     NaN      Mumbai                 Edtech
# 3           HomeLane 2014.00     Chennai        Interior design
# 4           Nu Genes 2004.00   Telangana               AgriTech
# ...              ...     ...         ...                    ...
# 1204        Gigforce 2019.00    Gurugram  Staffing & Recruiting
# 1205          Vahdam 2015.00   New Delhi       Food & Beverages
# 1206    Leap Finance 2019.00   Bangalore     Financial Services
# 1207    CollegeDekho 2015.00    Gurugram                 EdTech
# 1208          WeRize 2019.00   Bangalore     Financial Services
#
#                                            What it does  \
# 0            Provides a range of male grooming products
# 1     A learning platform that provides topic-based ...
# 2               It aims to make learning fun via games.
# 3                 Provides interior designing solutions
# 4     It is a seed company engaged in production, pr...
# ...                                                 ...
# 1204                  A gig/on-demand staffing company.
# 1205  VAHDAM is among the world’s first vertically i...
# 1206  International education loans for high potenti...
# 1207  Collegedekho.com is Student’s Partner, Friend ...
# 1208  India’s first socially distributed full stack ...
#
#                                    Founders  \
# 0                        Shantanu Deshpande
# 1     Adamas Belva Syah Devara, Iman Usman.
# 2                             Jatin Solanki
# 3              Srikanth Iyer, Rama Harinath
# 4                    Narayana Reddy Punyala
# ...                                     ...
# 1204            Chirag Mittal, Anirudh Syal
# 1205                             Bala Sarda
# 1206             Arnav Kumar, Vaibhav Singh
# 1207                           Ruchir Arora
# 1208          Vishal Chopra, Himanshu Gupta
#
#                                                Investor     Amount($)  \
# 0                                  Sixth Sense Ventures    $6,300,000
# 1                                      General Atlantic  $150,000,000
# 2        Deepak Parekh, Amitabh Bachchan, Piyush Pandey   $28,000,000
# 3     Evolvence India Fund (EIF), Pidilite Group, FJ...   $30,000,000
# 4              Innovation in Food and Agriculture (IFA)    $6,000,000
# ...                                                 ...           ...
# 1204                                    Endiya Partners      $3000000
# 1205                                           IIFL AMC     $20000000
# 1206                                       Owl Ventures     $55000000
# 1207                   Winter Capital, ETS, Man Capital     $26000000
# 1208                     3one4 Capital, Kalaari Capital      $8000000
#
#               Stage Unnamed: 9
# 0               NaN        NaN
# 1          Series C        NaN
# 2     Fresh funding        NaN
# 3          Series D        NaN
# 4               NaN        NaN
# ...             ...        ...
# 1204   Pre-series A        NaN
# 1205       Series D        NaN
# 1206       Series C        NaN
# 1207       Series B        NaN
# 1208       Series A        NaN
#
# [2353 rows x 10 columns]

# %% [markdown]
# #### Lets take a look at the unique values in each of the columns to get a general overview of what the table contains

# %%
df['Company/Brand'].unique()
# Out:
# array(['Bombay Shaving', 'Ruangguru', 'Eduisfun', ...,
#        'Cogos Technologies', 'Vahdam', 'WeRize'], dtype=object)

# %%
df['Founded'].unique()
# Out:
# array([nan, 2014.0, 2004.0, 2013.0, 2010.0, 2018.0, 2019.0, 2017.0,
#        2011.0, 2015.0, 2016.0, 2012.0, 2008.0, '2019', '2018', '2020',
#        '2016', '2008', '2015', '2017', '2014', '1998', '2007', '2011',
#        '1982', '2013', '2009', '2012', '1995', '2010', '2006', '1978',
#        '1999', '1994', '2005', '1973', '-', '2002', '2004', '2001',
#        2021.0, 2020.0, 1993.0, 1999.0, 1989.0, 2009.0, 2002.0, 1994.0,
#        2006.0, 2000.0, 2007.0, 1978.0, 2003.0, 1998.0, 1991.0, 1984.0,
#        2005.0, 1963.0], dtype=object)

# %%
df['HeadQuarter'].unique()
# Out:
# array([nan, 'Mumbai', 'Chennai', 'Telangana', 'Pune', 'Bangalore',
#        'Noida', 'Delhi', 'Ahmedabad', 'Gurugram', 'Haryana', 'Chandigarh',
#        'Jaipur', 'New Delhi', 'Surat', 'Uttar pradesh', 'Hyderabad',
#        'Rajasthan', 'Indore', 'Gurgaon', 'Belgaum', 'Andheri', 'Kolkata',
#        'Tirunelveli, Tamilnadu', 'Thane', 'Singapore', 'Gujarat',
#        'Kerala', 'Jodhpur', 'Jaipur, Rajastan',
#        'Frisco, Texas, United States', 'California', 'Dhingsara, Haryana',
#        'New York, United States', 'Patna',
#        'San Francisco, California, United States',
#        'San Francisco, United States', 'San Ramon, California',
#        'Paris, Ile-de-France, France', 'Plano, Texas, United States',
#        'Sydney', 'San Francisco Bay Area, Silicon Valley, West Coast',
#        'Bangaldesh', 'London, England, United Kingdom',
#        'Sydney, New South Wales, Australia', 'Milano, Lombardia, Italy',
#        'Palmwoods, Queensland, Australia', 'France',
#        'San Francisco Bay Area, West Coast, Western US',
#        'Trivandrum, Kerala, India', 'Cochin', 'Samastipur, Bihar',
#        'Irvine, California, United States', 'Tumkur, Karnataka',
#        'Newcastle Upon Tyne, Newcastle upon Tyne, United Kingdom',
#        'Shanghai, China', 'Jiaxing, Zhejiang, China', 'Rajastan', 'Kochi',
#        'Ludhiana', 'Dehradun', 'San Franciscao', 'San Francisco',
#        'Tangerang, Jawa Barat, Indonesia', 'Berlin', 'Seattle', 'Riyadh',
#        'Seoul', 'New York', 'Bangkok', 'Kanpur', 'Warangal', 'Hyderebad',
#        'Odisha', 'Bihar', 'Goa', 'Tamil Nadu', 'Uttar Pradesh', 'Bhopal',
#        'Banglore', 'Coimbatore', 'Bengaluru', 'Ahmadabad',
#        'Small Towns, Andhra Pradesh', 'Rajsamand', 'Ranchi',
#        'Faridabad, Haryana', 'Computer Games', 'Vadodara',
#        'Food & Beverages', 'Pharmaceuticals\t#REF!', 'Gurugram\t#REF!',
#        'Mohali', 'Powai', 'Ghaziabad', 'Nagpur', 'West Bengal',
#        'Samsitpur', 'Lucknow', 'Silvassa', 'Thiruvananthapuram',
#        'Faridabad', 'Roorkee', 'Ambernath', 'Panchkula', 'Mangalore',
#        'Telugana', 'Bhubaneswar', 'Kottayam', 'Beijing', 'Panaji',
#        'Satara', 'Orissia', 'Santra', 'Mountain View, CA', 'Trivandrum',
#        'Jharkhand', 'Bhilwara', 'Guwahati', 'Online Media\t#REF!',
#        'London', 'Information Technology & Services', 'The Nilgiris',
#        'Gandhinagar'], dtype=object)

# %%
df['Sector'].unique()
# Out:
# array(['Ecommerce', 'Edtech', 'Interior design', 'AgriTech', 'Technology',
#        'SaaS', 'AI & Tech', 'E-commerce', 'E-commerce & AR', 'Fintech',
#        'HR tech', 'Food tech', 'Health', 'Healthcare', 'Safety tech',
#        'Pharmaceutical', 'Insurance technology', 'AI', 'Foodtech', 'Food',
#        'IoT', 'E-marketplace', 'Robotics & AI', 'Logistics', 'Travel',
#        'Manufacturing', 'Food & Nutrition', 'Social Media', nan,
#        'E-Sports', 'Cosmetics', 'B2B', 'Jewellery', 'B2B Supply Chain',
#        'Games', 'Food & tech', 'Accomodation', 'Automotive tech',
#        'Legal tech', 'Mutual Funds', 'Cybersecurity', 'Automobile',
#        'Sports', 'Healthtech', 'Yoga & wellness', 'Virtual Banking',
#        'Transportation', 'Transport & Rentals',
#        'Marketing & Customer loyalty', 'Infratech', 'Hospitality',
#        'Automobile & Technology', 'Banking', 'EdTech',
#        'Hygiene management', 'Escrow', 'Networking platform', 'FinTech',
#        'Crowdsourcing', 'Food & Bevarages', 'HealthTech',
#        'Fashion startup', 'Food Industry', 'Food Delivery',
#        'Virtual auditing startup', 'Gaming', 'Work fulfillment',
#        'AI startup', 'Telecommunication', 'Tech Startup', 'Retail',
#        'Medtech', 'Tyre management', 'Cloud company', 'Software company',
#        'Venture capitalist', 'Renewable player', 'IoT startup',
#        'SaaS startup', 'Aero company', 'Marketing company',
#        'Retail startup', 'Co-working Startup', 'Finance company',
#        'Tech company', 'Solar Monitoring Company',
#        'Video sharing platform', 'Gaming startup',
#        'Video streaming platform', 'Consumer appliances',
#        'Blockchain startup', 'Conversational AI platform', 'Real Estate',
#        'SaaS platform', 'AI platform', 'Fusion beverages', 'HR Tech',
#        'Job portal', 'Digital Media', 'Dairy startup',
#        'Content management', 'Spacetech', 'Trading platform',
#        'AI Company', 'Photonics startup', 'Entertainment', 'Scanning app',
#        'Skincare startup', 'Food and Beverages', 'Biotechnology company',
#        'FoodTech', 'Proptech', 'CleanTech', 'Fitness startup',
#        'PaaS startup', 'Beverages', 'Automobiles', 'Deeptech',
#        'EV startup', 'AR/VR startup', 'Recruitment startup',
#        'QSR startup', 'Video platform', 'Fertility tech',
#        'Luxury car startup', 'FM', 'Nutrition sector', 'Tech platform',
#        'Video', 'Retail Tech', 'HeathTech', 'Sles and marketing',
#        'LegalTech', 'Car Service', 'Bike marketplace', 'Agri tech',
#        'Reatil startup', 'AR platform', 'Consumer Goods',
#        'Content marketplace', 'Interior Design', 'Rental space',
#        'Soil-Tech', 'Ayurveda tech', 'Packaging solution startup',
#        'Cleantech', 'Sanitation solutions', 'HealthCare', 'Home Design',
#        'InsureTech', 'AI Startup', 'Solar solution', 'Jewellery startup',
#        'Multinational conglomerate company', 'Deeptech startup',
#        'Social Network', 'Publication', 'Tech', 'Fashion', 'Finance',
#        'Venture capital', 'Entreprenurship', 'Food devlivery',
#        'Warehouse', 'Online financial service', 'Eyeglasses',
#        'Battery design', 'Online credit management startup', 'Beverage',
#        'TravelTech', 'Agriculture', 'Startup laboratory',
#        'Personal care startup', 'Customer service company',
#        'SaaS\xa0\xa0startup', 'Marketing startup', 'Service industry',
#        'Social media', 'AR startup', 'HR Tech startup',
#        'Automotive Startup', 'Food Startup', 'EdTech Startup',
#        'Car Trade', 'EdtTech', 'AI Platform', 'Automation', 'Solar SaaS',
#        'WL & RAC protection', 'Social commerce', 'Home interior services',
#        'Agritech startup', 'API platform', 'Deep Tech', 'Electricity',
#        'Automotive company', 'FMCG', 'Insurance Tech',
#        'Video personalization', 'Software Company', 'Biomaterial startup',
#        'IT', 'Craft Beer', 'Education', 'Investment',
#        'Linguistic Spiritual', 'Construction', 'Battery manufacturer',
#        'Nano Distribution Network', 'AI health', 'Dating app', 'Media',
#        'Healthcare/Edtech', 'Social Commerce', 'Agritech/Commerce',
#        'Mobility tech', 'Social e-commerce', 'Food & Logistics',
#        'SpaceTech', 'Nutrition Tech', 'HR', 'Agritech', 'AR/VR',
#        'Appliance', 'Mental Health', 'Solar Solution', 'B2B marketplace',
#        'Fashion Tech', 'Nutrition tech', 'Health & Wellness',
#        'Cloud Kitchen', 'IoT/Automobile', 'Eye Wear', 'Digital tech',
#        'Data Intelligence', 'Co-living', 'Food & Beverages', 'Automotive',
#        'Defense tech', 'Marketplace', 'Construction tech', 'Nutrition',
#        'Coworking', 'Micro-mobiity', 'Auto-tech', 'Beauty', 'Robotics',
#        'Logitech', 'Med Tech', 'Life sciences', 'Retail Aggregator',
#        'Deep Tech AI', 'Biotech', 'Blockchain', 'HrTech',
#        'Mobility/Transport', 'Rental', 'AI & Debt', 'SaaS/Edtech',
#        'Transport', 'Co-working', 'Insurtech', 'Cryptocurrency', 'Legal',
#        'Fitness', 'EV', 'Supply chain, Agritech', 'Pharma',
#        'Foodtech & Logistics', 'Housing', 'Data Analytics',
#        'Investment Tech', 'Financial Services', 'Biopharma', 'Dairy',
#        'Beauty & wellness', 'Travel & SaaS', 'Tourism & EV', 'Media Tech',
#        'Location Analytics', 'E store', 'Data Science', 'Insurance',
#        'Health and Fitness', 'Interior & decor', 'eMobility',
#        'Automation tech', 'Media & Networking', 'E-market',
#        'AI & Data science', 'Travel tech', 'Automotive and Rentals',
#        'E-tail', 'AI & Media', 'Machine Learning', 'Content Marktplace',
#        'Visual Media', 'Hygiene', 'VR & SaaS', 'Sales & Services',
#        'AI & Deep learning', 'Housing & Rentals', 'Estore', 'Marketing',
#        'E tailor', 'E-mobility', 'Ad-tech', 'Neo-banking',
#        'Transport Automation', 'Techonology', 'AI Robotics',
#        'Preschool Daycare', 'Food diet', 'B2B Agritech', 'E-connect',
#        'Tech hub', 'Consultancy', 'Pharmacy', 'Deisgning', 'Taxation',
#        'Automobile Technology', 'B2B E-commerce', 'Home services',
#        'B2B service', 'Helathcare', 'Renewable Energy', 'Electronics',
#        'IT startup', 'Aeorspace', 'Dating', 'Oil and Energy',
#        'Telecommuncation', 'Milk startup', 'AI Chatbot', 'Food delivery',
#        'Fantasy sports', 'Video communication', 'Skill development',
#        'Recruitment', 'Computer Games', 'Information Technology',
#        'Apparel & Fashion', 'Logistics & Supply Chain', 'SportsTech',
#        'HRTech', 'Wine & Spirits', 'Mechanical & Industrial Engineering',
#        'Spiritual', 'Industrial Automation', 'Lifestyle',
#        'Computer software', 'Tech startup', 'Digital mortgage',
#        'Information Technology & Services', 'Furniture', 'Healtcare',
#        'Consumer Electronics', 'Tobacco', 'Insuretech', 'MLOps platform',
#        'Venture Capital', 'Pet care', 'Drone', 'Wholesale', 'E-learning',
#        'Consumer Services', 'Venture Capital & Private Equity',
#        'Health, Wellness & Fitness', 'OTT', 'Education Management',
#        'Computer Software', 'Software Startup',
#        'Computer & Network Security', 'Capital Markets', 'Social network',
#        'Hospital & Health Care', 'Music', 'Hauz Khas',
#        'Primary Business is Development and Manufacturing of Novel Healthcare Products in Effervescent forms using imported propriety ingredients.',
#        "MoEVing is India's only Electric Mobility focused Technology Platform with a vision to accelerate EV adoption in India.",
#        'Mobility', 'Digital platform', 'B2B Ecommerce', 'Online Media',
#        'Mobile Games', 'Food Production', 'Podcast', 'Battery',
#        'Content publishing', 'Water purification', 'Content commerce',
#        'Innovation Management', 'Celebrity Engagement', 'Personal Care',
#        'Cannabis startup', 'Blogging', 'Consulting', 'BioTechnology',
#        'B2B Marketplace', 'Health care', 'Social audio',
#        'Fashion and lifestyle', 'Delivery service', 'B2B Manufacturing',
#        'Home Decor', 'Solar', 'TaaS startup', 'Manufacturing startup',
#        'Vehicle repair startup', 'Advisory firm', 'Legaltech',
#        'Pollution control equiptment', 'Fashion & Lifestyle', 'D2C',
#        'Environmental Services', 'Merchandise', 'Facilities Services',
#        'Marketing & Advertising', 'Human Resources', 'Eyewear',
#        'D2C Business', 'Biotechnology', 'Farming', 'NFT Marketplace',
#        'Internet', 'Consumer software', 'Social community', 'Fishery',
#        'Renewables & Environment', 'Online storytelling', 'Aviation',
#        'IT company', 'Environmental service', 'Job discovery platform',
#        'D2C Fashion', 'Heathcare', 'CRM', 'Software', 'D2C startup',
#        'Innovation management', 'Community platform', 'Networking',
#        'Commercial Real Estate', 'Consumer service', 'Consumer goods',
#        'MarTech', 'Advertisement', 'Content creation',
#        'Augmented reality', 'Bike Rental', 'Beauty products', 'Tourism',
#        'FemTech', 'Cultural', 'Supply chain platform', 'Social platform',
#        'Real estate', 'AI company', 'Sports startup', 'Matrimony',
#        'Crypto', 'Clothing', 'Analytics', 'IoT platform', 'Commerce',
#        'Defense & Space', 'Business Supplies & Equipment', 'NFT',
#        'Oil & Energy', 'Company-as-a-Service', 'Textiles',
#        'Professional Training & Coaching', 'Maritime',
#        'Housing Marketplace', 'Furniture Rental', 'Telecommunications',
#        'Equity Management', 'Cloud kitchen', 'Nanotechnology',
#        'Community', 'Higher Education',
#        'Mechanical Or Industrial Engineering', 'D2C jewellery',
#        'Sales and Distribution', 'Information Services',
#        'Translation & Localization', 'Investment Banking', 'Femtech',
#        'sports', 'Foootwear', 'Legal Services', 'Veterinary',
#        'Arts & Crafts', 'Investment Management', 'Management Consulting',
#        'B2B startup',
#        'Sochcast is an Audio experiences company that give the listener and creators an Immersive Audio experience',
#        'Design', 'B2B Travel', 'Manchester, Greater Manchester',
#        'Product studio', 'Aviation & Aerospace', 'Staffing & Recruiting'],
#       dtype=object)

# %%
df['What it does'].unique()
# Out:
# array(['Provides a range of male grooming products',
#        'A learning platform that provides topic-based journey, animated videos, quizzes, infographic and mock tests to students',
#        'It aims to make learning fun via games.', ...,
#        'International education loans for high potential students.',
#        'Collegedekho.com is Student’s Partner, Friend & Confidante, To Help Him Take a Decision and Move On to His Career Goals.',
#        'India’s first socially distributed full stack financial services platform for small town India'],
#       dtype=object)

# %% [markdown]
# # Feature Processing
# Here is the section to **clean** and **process** the features of the dataset.

# %% [markdown]
# ### Missing/NaN Values
# Each column is cleaned individually by first looking at the total number of empty rows and then extracting thoses rows and handle the missing/NaN values.

# %% [markdown]
# ### Founded Column

# %%
# Total Number of empty rows in the Founded Column 
df['Founded'].isnull().sum()
# Out:
# 242

# %%
# Extracting the row with  missing data in the Founded column
df[df['Founded'].isna()]
# Out:
#          Company/Brand Founded HeadQuarter      Sector  \
# 0       Bombay Shaving     NaN         NaN   Ecommerce
# 2             Eduisfun     NaN      Mumbai      Edtech
# 5             FlytBase     NaN        Pune  Technology
# 6                Finly     NaN   Bangalore        SaaS
# 8            Quantiphi     NaN         NaN   AI & Tech
# ...                ...     ...         ...         ...
# 1043            Quicko     NaN   Ahmedabad    Taxation
# 1044  Satin Creditcare     NaN     Gurgaon     Fintech
# 1050      Leverage Edu     NaN       Delhi      Edtech
# 1051             EpiFi     NaN         NaN     Fintech
# 137      Smart Express     NaN      Mumbai   Logistics
#
#                                            What it does  \
# 0            Provides a range of male grooming products
# 2               It aims to make learning fun via games.
# 5                           A drone automation platform
# 6     It builds software products that makes work si...
# 8     It is an AI and big data services company prov...
# ...                                                 ...
# 1043            Online tax planning and filing platform
# 1044                            A micro finance company
# 1050  AI enabled marketplace that provides career gu...
# 1051  It offers customers with a single interface fo...
# 137   India’s Most Innovative and Awarded Express Lo...
#
#                              Founders  \
# 0                  Shantanu Deshpande
# 2                       Jatin Solanki
# 5                         Nitin Gupta
# 6           Vivek AG, Veekshith C Rai
# 8                      Renuka Ramnath
# ...                               ...
# 1043               Vishvajit Sonagara
# 1044                              NaN
# 1050                Akshay Chaturvedi
# 1051  Sujith Narayanan, Sumit Gwalani
# 137                    Yogesh Dhingra
#
#                                                Investor    Amount($)  \
# 0                                  Sixth Sense Ventures   $6,300,000
# 2        Deepak Parekh, Amitabh Bachchan, Piyush Pandey  $28,000,000
# 5                                           Undisclosed  Undisclosed
# 6     Social Capital, AngelList India, Gemba Capital...  Undisclosed
# 8                  Multiples Alternate Asset Management  $20,000,000
# ...                                                 ...          ...
# 1043                   Zerodha fintech fund, Rainmatter     $280,000
# 1044                                      Austrian Bank  $15,000,000
# 1050              DSG Consumer Partners, Blume Ventures   $1,500,000
# 1051                      Sequoia India, Ribbit Capital  $13,200,000
# 137   IIFL India Private Equity Fund, Smiti Holding ...    $10000000
#
#               Stage Unnamed: 9
# 0               NaN        NaN
# 2     Fresh funding        NaN
# 5               NaN        NaN
# 6               NaN        NaN
# 8          Series A        NaN
# ...             ...        ...
# 1043            NaN        NaN
# 1044            NaN        NaN
# 1050            NaN        NaN
# 1051     Seed Round        NaN
# 137            Seed        NaN
#
# [242 rows x 10 columns]

# %%
# fill NaN rows with 0

df['Founded'] = df['Founded'].replace(np.nan, 0)

# %%
# filling rows with - with 0

df['Founded'] = df['Founded'].replace('-',0)

# %%
#Change the datatype of Founded column from Float to int first to remove the decimal

df['Founded'] = df['Founded'].astype(int)

# %%
#Replace the missing data in Founders column with 'N/A'

df['Founded'] = df['Founded'].replace(0, 'N/A')

# %%
#Change the datatype of Founded column from Float to string 

df['Founded'] = df['Founded'].astype(str)

# %%
df
# Out:
#        Company/Brand Founded HeadQuarter                 Sector  \
# 0     Bombay Shaving     N/A         NaN              Ecommerce
# 1          Ruangguru    2014      Mumbai                 Edtech
# 2           Eduisfun     N/A      Mumbai                 Edtech
# 3           HomeLane    2014     Chennai        Interior design
# 4           Nu Genes    2004   Telangana               AgriTech
# ...              ...     ...         ...                    ...
# 1204        Gigforce    2019    Gurugram  Staffing & Recruiting
# 1205          Vahdam    2015   New Delhi       Food & Beverages
# 1206    Leap Finance    2019   Bangalore     Financial Services
# 1207    CollegeDekho    2015    Gurugram                 EdTech
# 1208          WeRize    2019   Bangalore     Financial Services
#
#                                            What it does  \
# 0            Provides a range of male grooming products
# 1     A learning platform that provides topic-based ...
# 2               It aims to make learning fun via games.
# 3                 Provides interior designing solutions
# 4     It is a seed company engaged in production, pr...
# ...                                                 ...
# 1204                  A gig/on-demand staffing company.
# 1205  VAHDAM is among the world’s first vertically i...
# 1206  International education loans for high potenti...
# 1207  Collegedekho.com is Student’s Partner, Friend ...
# 1208  India’s first socially distributed full stack ...
#
#                                    Founders  \
# 0                        Shantanu Deshpande
# 1     Adamas Belva Syah Devara, Iman Usman.
# 2                             Jatin Solanki
# 3              Srikanth Iyer, Rama Harinath
# 4                    Narayana Reddy Punyala
# ...                                     ...
# 1204            Chirag Mittal, Anirudh Syal
# 1205                             Bala Sarda
# 1206             Arnav Kumar, Vaibhav Singh
# 1207                           Ruchir Arora
# 1208          Vishal Chopra, Himanshu Gupta
#
#                                                Investor     Amount($)  \
# 0                                  Sixth Sense Ventures    $6,300,000
# 1                                      General Atlantic  $150,000,000
# 2        Deepak Parekh, Amitabh Bachchan, Piyush Pandey   $28,000,000
# 3     Evolvence India Fund (EIF), Pidilite Group, FJ...   $30,000,000
# 4              Innovation in Food and Agriculture (IFA)    $6,000,000
# ...                                                 ...           ...
# 1204                                    Endiya Partners      $3000000
# 1205                                           IIFL AMC     $20000000
# 1206                                       Owl Ventures     $55000000
# 1207                   Winter Capital, ETS, Man Capital     $26000000
# 1208                     3one4 Capital, Kalaari Capital      $8000000
#
#               Stage Unnamed: 9
# 0               NaN        NaN
# 1          Series C        NaN
# 2     Fresh funding        NaN
# 3          Series D        NaN
# 4               NaN        NaN
# ...             ...        ...
# 1204   Pre-series A        NaN
# 1205       Series D        NaN
# 1206       Series C        NaN
# 1207       Series B        NaN
# 1208       Series A        NaN
#
# [2353 rows x 10 columns]

# %% [markdown]
# #### Data types of HeadQuater, Sector, What it does, Founders, Investor and Stage are the same.  So we replace all missing data in those columns with 'N/A'

# %%
#updating the columns 

df.update(df[['HeadQuarter','Sector','What it does', 'Founders', 'Investor','Stage']].fillna('N/A'))

# %%
df
# Out:
#        Company/Brand Founded HeadQuarter                 Sector  \
# 0     Bombay Shaving     N/A         N/A              Ecommerce
# 1          Ruangguru    2014      Mumbai                 Edtech
# 2           Eduisfun     N/A      Mumbai                 Edtech
# 3           HomeLane    2014     Chennai        Interior design
# 4           Nu Genes    2004   Telangana               AgriTech
# ...              ...     ...         ...                    ...
# 1204        Gigforce    2019    Gurugram  Staffing & Recruiting
# 1205          Vahdam    2015   New Delhi       Food & Beverages
# 1206    Leap Finance    2019   Bangalore     Financial Services
# 1207    CollegeDekho    2015    Gurugram                 EdTech
# 1208          WeRize    2019   Bangalore     Financial Services
#
#                                            What it does  \
# 0            Provides a range of male grooming products
# 1     A learning platform that provides topic-based ...
# 2               It aims to make learning fun via games.
# 3                 Provides interior designing solutions
# 4     It is a seed company engaged in production, pr...
# ...                                                 ...
# 1204                  A gig/on-demand staffing company.
# 1205  VAHDAM is among the world’s first vertically i...
# 1206  International education loans for high potenti...
# 1207  Collegedekho.com is Student’s Partner, Friend ...
# 1208  India’s first socially distributed full stack ...
#
#                                    Founders  \
# 0                        Shantanu Deshpande
# 1     Adamas Belva Syah Devara, Iman Usman.
# 2                             Jatin Solanki
# 3              Srikanth Iyer, Rama Harinath
# 4                    Narayana Reddy Punyala
# ...                                     ...
# 1204            Chirag Mittal, Anirudh Syal
# 1205                             Bala Sarda
# 1206             Arnav Kumar, Vaibhav Singh
# 1207                           Ruchir Arora
# 1208          Vishal Chopra, Himanshu Gupta
#
#                                                Investor     Amount($)  \
# 0                                  Sixth Sense Ventures    $6,300,000
# 1                                      General Atlantic  $150,000,000
# 2        Deepak Parekh, Amitabh Bachchan, Piyush Pandey   $28,000,000
# 3     Evolvence India Fund (EIF), Pidilite Group, FJ...   $30,000,000
# 4              Innovation in Food and Agriculture (IFA)    $6,000,000
# ...                                                 ...           ...
# 1204                                    Endiya Partners      $3000000
# 1205                                           IIFL AMC     $20000000
# 1206                                       Owl Ventures     $55000000
# 1207                   Winter Capital, ETS, Man Capital     $26000000
# 1208                     3one4 Capital, Kalaari Capital      $8000000
#
#               Stage Unnamed: 9
# 0               N/A        NaN
# 1          Series C        NaN
# 2     Fresh funding        NaN
# 3          Series D        NaN
# 4               N/A        NaN
# ...             ...        ...
# 1204   Pre-series A        NaN
# 1205       Series D        NaN
# 1206       Series C        NaN
# 1207       Series B        NaN
# 1208       Series A        NaN
#
# [2353 rows x 10 columns]

# %% [markdown]
# ### Unnamed Column

# %%
# A look at Unnamed: 9 column 

df['Unnamed: 9'].unique()
# Out:
# array([nan, 'Pre-Seed', 'Seed Round'], dtype=object)

# %%
# A careful look at the Stage column and the unnamed column shows that data from the stage column, moved to the unanmed column

# %%
#Extracting rows with values ie negative na (- na) in the unnamed column. This will enable us deduce which rows have value in the unnamed column
df[-df['Unnamed: 9'].isna()]
# Out:
#     Company/Brand Founded HeadQuarter   Sector  \
# 611        Walrus    2019   Bangalore  Fintech
# 613       goDutch     N/A      Mumbai  Fintech
#
#                                           What it does  \
# 611  It provides banking solutions for teens and yo...
# 613                            Group Payments platform
#
#                                             Founders  \
# 611  Bhagaban Behera, Sriharsha Shetty, Nakul Kelkar
# 613          Aniruddh Singh, Riyaz Khan, Sagar Sheth
#
#                                               Investor    Amount($)  \
# 611                                     Better Capital  Undisclosed
# 613  Matrix India, Y Combinator, Global Founders Ca...   $1,700,000
#
#           Stage  Unnamed: 9
# 611    Pre-Seed    Pre-Seed
# 613  Seed Round  Seed Round

# %%
# Since the column is just a repetition of the Stage column, the unnamed column is droped. 
df.drop('Unnamed: 9', inplace=True, axis=1)

# %% [markdown]
# ### Stage Column

# %%
df['Stage'].unique()
# Out:
# array(['N/A', 'Series C', 'Fresh funding', 'Series D', 'Pre series A',
#        'Series A', 'Series G', 'Series B', 'Post series A',
#        'Seed funding', 'Seed fund', 'Series E', 'Series F', 'Series B+',
#        'Seed round', 'Pre-series A', 'Pre-seed', 'Seed', 'Pre-series',
#        'Debt', 'Pre-series C', 'Pre-series B', 'Bridge', 'Series B2',
#        'Pre- series A', 'Edge', 'Series H', 'Pre-Series B', 'Seed A',
#        'Series A-1', 'Seed Funding', 'Pre-Seed', 'Pre-seed Round',
#        'Seed Round & Series A', 'Pre Series A', 'Pre seed Round',
#        'Angel Round', 'Pre series A1', 'Series E2', 'Seed Round',
#        'Bridge Round', 'Pre seed round', 'Pre series B', 'Pre series C',
#        'Seed Investment', 'Series D1', 'Mid series', 'Series C, D',
#        '$1200000', 'Seed+', 'Series F2', 'Series A+', 'Series B3', 'PE',
#        'Series F1', 'Pre-series A1', '$300000', 'Early seed', '$6000000',
#        '$1000000', 'Seies A', 'Series A2', 'Series I'], dtype=object)

# %%
# Stage column also contains amounts. Lets extract the rows with figures in them using the $ sign as our condition . 
df[df['Stage'].str.contains('\$')]
# Out:
#         Company/Brand Founded     HeadQuarter                  Sector  \
# 98            FanPlay    2020  Computer Games          Computer Games
# 111           FanPlay    2020  Computer Games          Computer Games
# 538       Little Leap    2020       New Delhi                  EdTech
# 551             BHyve    2020          Mumbai         Human Resources
# 674      MYRE Capital    2020          Mumbai  Commercial Real Estate
# 677  Saarthi Pedagogy    2015       Ahmadabad                  EdTech
#
#                                           What it does  \
# 98   A real money game app specializing in trivia g...
# 111  A real money game app specializing in trivia g...
# 538                Soft Skills that make Smart Leaders
# 551  A Future of Work Platform for diffusing Employ...
# 674                Democratising Real Estate Ownership
# 677  India's fastest growing Pedagogy company, serv...
#
#                                               Founders  \
# 98                                              YC W21
# 111                                             YC W21
# 538  Holistic Development Programs for children in ...
# 551                                  Backed by 100x.VC
# 674            Own rent yielding commercial properties
# 677                                           Pedagogy
#
#                             Investor                        Amount($)  \
# 98       Pritesh Kumar, Bharat Gupta                         Upsparks
# 111      Pritesh Kumar, Bharat Gupta                         Upsparks
# 538                     Vishal Gupta                     ah! Ventures
# 551  Omkar Pandharkame, Ketaki Ogale   ITO Angel Network, LetsVenture
# 674                      Aryaman Vir                              NaN
# 677                   Sushil Agarwal  JITO Angel Network, LetsVenture
#
#         Stage
# 98   $1200000
# 111  $1200000
# 538   $300000
# 551   $300000
# 674  $6000000
# 677  $1000000

# %%
#Remove all amount values with $ sign in the Stage column and put them in the Amount ($) colum

new = df['Stage'].str.contains('\$')
df.loc[new, ['Stage', 'Amount($)']] = df.loc[new, ['Amount($)', 'Stage']].to_numpy()

# %%
#Lets check the column again and make sure the stage column does not have any values with $ sign.

df[df['Stage'].str.contains('\$',na=False)]
# Out:
# Empty DataFrame
# Columns: [Company/Brand, Founded, HeadQuarter, Sector, What it does, Founders, Investor, Amount($), Stage]
# Index: []

# %%
# Lets inspect the stage column by looking at the unique values 
df['Stage'].unique()
# Out:
# array(['N/A', 'Series C', 'Fresh funding', 'Series D', 'Pre series A',
#        'Series A', 'Series G', 'Series B', 'Post series A',
#        'Seed funding', 'Seed fund', 'Series E', 'Series F', 'Series B+',
#        'Seed round', 'Pre-series A', 'Pre-seed', 'Seed', 'Pre-series',
#        'Debt', 'Pre-series C', 'Pre-series B', 'Bridge', 'Series B2',
#        'Pre- series A', 'Edge', 'Series H', 'Pre-Series B', 'Seed A',
#        'Series A-1', 'Seed Funding', 'Pre-Seed', 'Pre-seed Round',
#        'Seed Round & Series A', 'Pre Series A', 'Pre seed Round',
#        'Angel Round', 'Pre series A1', 'Series E2', 'Seed Round',
#        'Bridge Round', 'Pre seed round', 'Pre series B', 'Pre series C',
#        'Seed Investment', 'Series D1', 'Mid series', 'Series C, D',
#        'Upsparks', 'Seed+', 'Series F2', 'Series A+', 'Series B3', 'PE',
#        'Series F1', 'Pre-series A1', 'ah! Ventures',
#        'ITO Angel Network, LetsVenture', 'Early seed', nan,
#        'JITO Angel Network, LetsVenture', 'Seies A', 'Series A2',
#        'Series I'], dtype=object)

# %%
# Extract columns with foreign values
df[df['Stage'].str.contains('venture|network|upsparks',case=False, na=False)]
# Out:
#         Company/Brand Founded     HeadQuarter           Sector  \
# 98            FanPlay    2020  Computer Games   Computer Games
# 111           FanPlay    2020  Computer Games   Computer Games
# 538       Little Leap    2020       New Delhi           EdTech
# 551             BHyve    2020          Mumbai  Human Resources
# 677  Saarthi Pedagogy    2015       Ahmadabad           EdTech
#
#                                           What it does  \
# 98   A real money game app specializing in trivia g...
# 111  A real money game app specializing in trivia g...
# 538                Soft Skills that make Smart Leaders
# 551  A Future of Work Platform for diffusing Employ...
# 677  India's fastest growing Pedagogy company, serv...
#
#                                               Founders  \
# 98                                              YC W21
# 111                                             YC W21
# 538  Holistic Development Programs for children in ...
# 551                                  Backed by 100x.VC
# 677                                           Pedagogy
#
#                             Investor Amount($)  \
# 98       Pritesh Kumar, Bharat Gupta  $1200000
# 111      Pritesh Kumar, Bharat Gupta  $1200000
# 538                     Vishal Gupta   $300000
# 551  Omkar Pandharkame, Ketaki Ogale   $300000
# 677                   Sushil Agarwal  $1000000
#
#                                Stage
# 98                          Upsparks
# 111                         Upsparks
# 538                     ah! Ventures
# 551   ITO Angel Network, LetsVenture
# 677  JITO Angel Network, LetsVenture

# %%
#replace foreign values with N/A
df.loc[df['Stage'].str.contains('venture|network|upsparks|PE', case=False, na=False), 'Stage'] = 'N/A'

# %%
df['Stage'].unique()
# Out:
# array(['N/A', 'Series C', 'Fresh funding', 'Series D', 'Pre series A',
#        'Series A', 'Series G', 'Series B', 'Post series A',
#        'Seed funding', 'Seed fund', 'Series E', 'Series F', 'Series B+',
#        'Seed round', 'Pre-series A', 'Pre-seed', 'Seed', 'Pre-series',
#        'Debt', 'Pre-series C', 'Pre-series B', 'Bridge', 'Series B2',
#        'Pre- series A', 'Edge', 'Series H', 'Pre-Series B', 'Seed A',
#        'Series A-1', 'Seed Funding', 'Pre-Seed', 'Pre-seed Round',
#        'Seed Round & Series A', 'Pre Series A', 'Pre seed Round',
#        'Angel Round', 'Pre series A1', 'Series E2', 'Seed Round',
#        'Bridge Round', 'Pre seed round', 'Pre series B', 'Pre series C',
#        'Seed Investment', 'Series D1', 'Mid series', 'Series C, D',
#        'Seed+', 'Series F2', 'Series A+', 'Series B3', 'Series F1',
#        'Pre-series A1', 'Early seed', nan, 'Seies A', 'Series A2',
#        'Series I'], dtype=object)

# %%
#replace misspelled stage names with the appropriate stage names 
df['Stage'] = df['Stage'].replace({'Seed+':'Seed','Seed Round & Series A':'Series A','Seies A':'Series A','Series A-1':'Series A',
                                  'Series C,D':'Series C','Seed funding':'Seed','Seed fund':'Seed','Seed round':'Seed'}, regex=True)

# %% [markdown]
# ### HeadQuater

# %%
df['HeadQuarter'].unique()
# Out:
# array(['N/A', 'Mumbai', 'Chennai', 'Telangana', 'Pune', 'Bangalore',
#        'Noida', 'Delhi', 'Ahmedabad', 'Gurugram', 'Haryana', 'Chandigarh',
#        'Jaipur', 'New Delhi', 'Surat', 'Uttar pradesh', 'Hyderabad',
#        'Rajasthan', 'Indore', 'Gurgaon', 'Belgaum', 'Andheri', 'Kolkata',
#        'Tirunelveli, Tamilnadu', 'Thane', 'Singapore', 'Gujarat',
#        'Kerala', 'Jodhpur', 'Jaipur, Rajastan',
#        'Frisco, Texas, United States', 'California', 'Dhingsara, Haryana',
#        'New York, United States', 'Patna',
#        'San Francisco, California, United States',
#        'San Francisco, United States', 'San Ramon, California',
#        'Paris, Ile-de-France, France', 'Plano, Texas, United States',
#        'Sydney', 'San Francisco Bay Area, Silicon Valley, West Coast',
#        'Bangaldesh', 'London, England, United Kingdom',
#        'Sydney, New South Wales, Australia', 'Milano, Lombardia, Italy',
#        'Palmwoods, Queensland, Australia', 'France',
#        'San Francisco Bay Area, West Coast, Western US',
#        'Trivandrum, Kerala, India', 'Cochin', 'Samastipur, Bihar',
#        'Irvine, California, United States', 'Tumkur, Karnataka',
#        'Newcastle Upon Tyne, Newcastle upon Tyne, United Kingdom',
#        'Shanghai, China', 'Jiaxing, Zhejiang, China', 'Rajastan', 'Kochi',
#        'Ludhiana', 'Dehradun', 'San Franciscao', 'San Francisco',
#        'Tangerang, Jawa Barat, Indonesia', 'Berlin', 'Seattle', 'Riyadh',
#        'Seoul', 'New York', 'Bangkok', 'Kanpur', 'Warangal', 'Hyderebad',
#        'Odisha', 'Bihar', 'Goa', 'Tamil Nadu', 'Uttar Pradesh', 'Bhopal',
#        'Banglore', 'Coimbatore', 'Bengaluru', 'Ahmadabad',
#        'Small Towns, Andhra Pradesh', 'Rajsamand', 'Ranchi',
#        'Faridabad, Haryana', 'Computer Games', 'Vadodara',
#        'Food & Beverages', 'Pharmaceuticals\t#REF!', 'Gurugram\t#REF!',
#        'Mohali', 'Powai', 'Ghaziabad', 'Nagpur', 'West Bengal',
#        'Samsitpur', 'Lucknow', 'Silvassa', 'Thiruvananthapuram',
#        'Faridabad', 'Roorkee', 'Ambernath', 'Panchkula', 'Mangalore',
#        'Telugana', 'Bhubaneswar', 'Kottayam', 'Beijing', 'Panaji',
#        'Satara', 'Orissia', 'Santra', 'Mountain View, CA', 'Trivandrum',
#        'Jharkhand', 'Bhilwara', 'Guwahati', 'Online Media\t#REF!',
#        'London', 'Information Technology & Services', 'The Nilgiris',
#        'Gandhinagar'], dtype=object)

# %%
#remove t#REF!from names in headquarters

df['HeadQuarter'] = df['HeadQuarter'].replace({'\t#REF!': ''}, regex=True)

# %%
# from our unique function, we see that food and beverages, pharmaceuticals and Information Technology & Services
# are in our headquarter column. Lets extract them 

df[df['HeadQuarter'].str.contains('Information Technology & Services|Online Media|Pharmaceuticals|Computer Games',case=False, na=False)]
# Out:
#            Company/Brand Founded                        HeadQuarter  \
# 98               FanPlay    2020                     Computer Games
# 111              FanPlay    2020                     Computer Games
# 242   Fullife Healthcare    2009                    Pharmaceuticals
# 256   Fullife Healthcare    2009                    Pharmaceuticals
# 1100            Sochcast    2020                       Online Media
# 1176                Peak    2014  Information Technology & Services
#
#                                                  Sector  \
# 98                                       Computer Games
# 111                                      Computer Games
# 242   Primary Business is Development and Manufactur...
# 256   Primary Business is Development and Manufactur...
# 1100  Sochcast is an Audio experiences company that ...
# 1176                     Manchester, Greater Manchester
#
#                                            What it does  \
# 98    A real money game app specializing in trivia g...
# 111   A real money game app specializing in trivia g...
# 242                                        Varun Khanna
# 256                                        Varun Khanna
# 1100  CA Harvinderjit Singh Bhatia, Garima Surana, A...
# 1176  Peak helps the world's smartest companies put ...
#
#                                      Founders                     Investor  \
# 98                                     YC W21  Pritesh Kumar, Bharat Gupta
# 111                                    YC W21  Pritesh Kumar, Bharat Gupta
# 242        Morgan Stanley Private Equity Asia                    $22000000
# 256        Morgan Stanley Private Equity Asia                    $22000000
# 1100  Vinners, Raj Nayak, Amritaanshu Agrawal                 $Undisclosed
# 1176                              Atul Sharma       SoftBank Vision Fund 2
#
#       Amount($)     Stage
# 98     $1200000       N/A
# 111    $1200000       N/A
# 242    Series C       N/A
# 256    Series C       N/A
# 1100        NaN       N/A
# 1176  $75000000  Series C

# %%
#moving values from the wrong columns to their appropriate  column

h= df['HeadQuarter'].str.contains('Pharmaceuticals')
df.loc[h, ['HeadQuarter', 'Sector','What it does']] = df.loc[h, ['What it does', 'HeadQuarter','Sector']].to_numpy()

# %%
df[df['HeadQuarter'].str.contains('Online Media')]
# Out:
#      Company/Brand Founded   HeadQuarter  \
# 1100      Sochcast    2020  Online Media
#
#                                                  Sector  \
# 1100  Sochcast is an Audio experiences company that ...
#
#                                            What it does  \
# 1100  CA Harvinderjit Singh Bhatia, Garima Surana, A...
#
#                                      Founders      Investor Amount($) Stage
# 1100  Vinners, Raj Nayak, Amritaanshu Agrawal  $Undisclosed       NaN   N/A

# %%
#moving values from the wrong columns to their appropriate  column

s=df['HeadQuarter'].str.contains('Online Media')
df.loc[s, ['Sector', 'What it does']] = df.loc[s, ['HeadQuarter','Sector']].to_numpy()

# %%
#moving values from the wrong columns to their appropriate  column

t= df['HeadQuarter'].str.contains('Information Technology & Services')
df.loc[t,['HeadQuarter','Sector']] = df.loc[t, ['Sector','HeadQuarter']].to_numpy()

# %%
df[df['HeadQuarter'].str.contains('Online Media')]
# Out:
#      Company/Brand Founded   HeadQuarter        Sector  \
# 1100      Sochcast    2020  Online Media  Online Media
#
#                                            What it does  \
# 1100  Sochcast is an Audio experiences company that ...
#
#                                      Founders      Investor Amount($) Stage
# 1100  Vinners, Raj Nayak, Amritaanshu Agrawal  $Undisclosed       NaN   N/A

# %%
# SInce the HeadQuater of Sochcast cant be determined, we replace it with N/A

df['HeadQuarter']= df['HeadQuarter'].replace({'Online Media':'N/A','Computer Games':'N/A'}, regex = True)

# %% [markdown]
# ### Sector Column

# %%
df['Sector'].unique()
# Out:
# array(['Ecommerce', 'Edtech', 'Interior design', 'AgriTech', 'Technology',
#        'SaaS', 'AI & Tech', 'E-commerce', 'E-commerce & AR', 'Fintech',
#        'HR tech', 'Food tech', 'Health', 'Healthcare', 'Safety tech',
#        'Pharmaceutical', 'Insurance technology', 'AI', 'Foodtech', 'Food',
#        'IoT', 'E-marketplace', 'Robotics & AI', 'Logistics', 'Travel',
#        'Manufacturing', 'Food & Nutrition', 'Social Media', 'N/A',
#        'E-Sports', 'Cosmetics', 'B2B', 'Jewellery', 'B2B Supply Chain',
#        'Games', 'Food & tech', 'Accomodation', 'Automotive tech',
#        'Legal tech', 'Mutual Funds', 'Cybersecurity', 'Automobile',
#        'Sports', 'Healthtech', 'Yoga & wellness', 'Virtual Banking',
#        'Transportation', 'Transport & Rentals',
#        'Marketing & Customer loyalty', 'Infratech', 'Hospitality',
#        'Automobile & Technology', 'Banking', 'EdTech',
#        'Hygiene management', 'Escrow', 'Networking platform', 'FinTech',
#        'Crowdsourcing', 'Food & Bevarages', 'HealthTech',
#        'Fashion startup', 'Food Industry', 'Food Delivery',
#        'Virtual auditing startup', 'Gaming', 'Work fulfillment',
#        'AI startup', 'Telecommunication', 'Tech Startup', 'Retail',
#        'Medtech', 'Tyre management', 'Cloud company', 'Software company',
#        'Venture capitalist', 'Renewable player', 'IoT startup',
#        'SaaS startup', 'Aero company', 'Marketing company',
#        'Retail startup', 'Co-working Startup', 'Finance company',
#        'Tech company', 'Solar Monitoring Company',
#        'Video sharing platform', 'Gaming startup',
#        'Video streaming platform', 'Consumer appliances',
#        'Blockchain startup', 'Conversational AI platform', 'Real Estate',
#        'SaaS platform', 'AI platform', 'Fusion beverages', 'HR Tech',
#        'Job portal', 'Digital Media', 'Dairy startup',
#        'Content management', 'Spacetech', 'Trading platform',
#        'AI Company', 'Photonics startup', 'Entertainment', 'Scanning app',
#        'Skincare startup', 'Food and Beverages', 'Biotechnology company',
#        'FoodTech', 'Proptech', 'CleanTech', 'Fitness startup',
#        'PaaS startup', 'Beverages', 'Automobiles', 'Deeptech',
#        'EV startup', 'AR/VR startup', 'Recruitment startup',
#        'QSR startup', 'Video platform', 'Fertility tech',
#        'Luxury car startup', 'FM', 'Nutrition sector', 'Tech platform',
#        'Video', 'Retail Tech', 'HeathTech', 'Sles and marketing',
#        'LegalTech', 'Car Service', 'Bike marketplace', 'Agri tech',
#        'Reatil startup', 'AR platform', 'Consumer Goods',
#        'Content marketplace', 'Interior Design', 'Rental space',
#        'Soil-Tech', 'Ayurveda tech', 'Packaging solution startup',
#        'Cleantech', 'Sanitation solutions', 'HealthCare', 'Home Design',
#        'InsureTech', 'AI Startup', 'Solar solution', 'Jewellery startup',
#        'Multinational conglomerate company', 'Deeptech startup',
#        'Social Network', 'Publication', 'Tech', 'Fashion', 'Finance',
#        'Venture capital', 'Entreprenurship', 'Food devlivery',
#        'Warehouse', 'Online financial service', 'Eyeglasses',
#        'Battery design', 'Online credit management startup', 'Beverage',
#        'TravelTech', 'Agriculture', 'Startup laboratory',
#        'Personal care startup', 'Customer service company',
#        'SaaS\xa0\xa0startup', 'Marketing startup', 'Service industry',
#        'Social media', 'AR startup', 'HR Tech startup',
#        'Automotive Startup', 'Food Startup', 'EdTech Startup',
#        'Car Trade', 'EdtTech', 'AI Platform', 'Automation', 'Solar SaaS',
#        'WL & RAC protection', 'Social commerce', 'Home interior services',
#        'Agritech startup', 'API platform', 'Deep Tech', 'Electricity',
#        'Automotive company', 'FMCG', 'Insurance Tech',
#        'Video personalization', 'Software Company', 'Biomaterial startup',
#        'IT', 'Craft Beer', 'Education', 'Investment',
#        'Linguistic Spiritual', 'Construction', 'Battery manufacturer',
#        'Nano Distribution Network', 'AI health', 'Dating app', 'Media',
#        'Healthcare/Edtech', 'Social Commerce', 'Agritech/Commerce',
#        'Mobility tech', 'Social e-commerce', 'Food & Logistics',
#        'SpaceTech', 'Nutrition Tech', 'HR', 'Agritech', 'AR/VR',
#        'Appliance', 'Mental Health', 'Solar Solution', 'B2B marketplace',
#        'Fashion Tech', 'Nutrition tech', 'Health & Wellness',
#        'Cloud Kitchen', 'IoT/Automobile', 'Eye Wear', 'Digital tech',
#        'Data Intelligence', 'Co-living', 'Food & Beverages', 'Automotive',
#        'Defense tech', 'Marketplace', 'Construction tech', 'Nutrition',
#        'Coworking', 'Micro-mobiity', 'Auto-tech', 'Beauty', 'Robotics',
#        'Logitech', 'Med Tech', 'Life sciences', 'Retail Aggregator',
#        'Deep Tech AI', 'Biotech', 'Blockchain', 'HrTech',
#        'Mobility/Transport', 'Rental', 'AI & Debt', 'SaaS/Edtech',
#        'Transport', 'Co-working', 'Insurtech', 'Cryptocurrency', 'Legal',
#        'Fitness', 'EV', 'Supply chain, Agritech', 'Pharma',
#        'Foodtech & Logistics', 'Housing', 'Data Analytics',
#        'Investment Tech', 'Financial Services', 'Biopharma', 'Dairy',
#        'Beauty & wellness', 'Travel & SaaS', 'Tourism & EV', 'Media Tech',
#        'Location Analytics', 'E store', 'Data Science', 'Insurance',
#        'Health and Fitness', 'Interior & decor', 'eMobility',
#        'Automation tech', 'Media & Networking', 'E-market',
#        'AI & Data science', 'Travel tech', 'Automotive and Rentals',
#        'E-tail', 'AI & Media', 'Machine Learning', 'Content Marktplace',
#        'Visual Media', 'Hygiene', 'VR & SaaS', 'Sales & Services',
#        'AI & Deep learning', 'Housing & Rentals', 'Estore', 'Marketing',
#        'E tailor', 'E-mobility', 'Ad-tech', 'Neo-banking',
#        'Transport Automation', 'Techonology', 'AI Robotics',
#        'Preschool Daycare', 'Food diet', 'B2B Agritech', 'E-connect',
#        'Tech hub', 'Consultancy', 'Pharmacy', 'Deisgning', 'Taxation',
#        'Automobile Technology', 'B2B E-commerce', 'Home services',
#        'B2B service', 'Helathcare', 'Renewable Energy', 'Electronics',
#        'IT startup', 'Aeorspace', 'Dating', 'Oil and Energy',
#        'Telecommuncation', 'Milk startup', 'AI Chatbot', 'Food delivery',
#        'Fantasy sports', 'Video communication', 'Skill development',
#        'Recruitment', 'Computer Games', 'Information Technology',
#        'Apparel & Fashion', 'Logistics & Supply Chain', 'SportsTech',
#        'HRTech', 'Wine & Spirits', 'Mechanical & Industrial Engineering',
#        'Spiritual', 'Industrial Automation', 'Lifestyle',
#        'Computer software', 'Tech startup', 'Digital mortgage',
#        'Information Technology & Services', 'Furniture', 'Healtcare',
#        'Consumer Electronics', 'Tobacco', 'Insuretech', 'MLOps platform',
#        'Venture Capital', 'Pet care', 'Drone', 'Wholesale', 'E-learning',
#        'Consumer Services', 'Venture Capital & Private Equity',
#        'Health, Wellness & Fitness', 'OTT', 'Education Management',
#        'Computer Software', 'Software Startup',
#        'Computer & Network Security', 'Capital Markets', 'Social network',
#        'Hospital & Health Care', 'Music', 'Hauz Khas', 'Pharmaceuticals',
#        "MoEVing is India's only Electric Mobility focused Technology Platform with a vision to accelerate EV adoption in India.",
#        'Mobility', 'Digital platform', 'B2B Ecommerce', 'Online Media',
#        'Mobile Games', 'Food Production', 'Podcast', 'Battery',
#        'Content publishing', 'Water purification', 'Content commerce',
#        'Innovation Management', 'Celebrity Engagement', 'Personal Care',
#        'Cannabis startup', 'Blogging', 'Consulting', 'BioTechnology',
#        'B2B Marketplace', 'Health care', 'Social audio',
#        'Fashion and lifestyle', 'Delivery service', 'B2B Manufacturing',
#        'Home Decor', 'Solar', 'TaaS startup', 'Manufacturing startup',
#        'Vehicle repair startup', 'Advisory firm', 'Legaltech',
#        'Pollution control equiptment', 'Fashion & Lifestyle', 'D2C',
#        'Environmental Services', 'Merchandise', 'Facilities Services',
#        'Marketing & Advertising', 'Human Resources', 'Eyewear',
#        'D2C Business', 'Biotechnology', 'Farming', 'NFT Marketplace',
#        'Internet', 'Consumer software', 'Social community', 'Fishery',
#        'Renewables & Environment', 'Online storytelling', 'Aviation',
#        'IT company', 'Environmental service', 'Job discovery platform',
#        'D2C Fashion', 'Heathcare', 'CRM', 'Software', 'D2C startup',
#        'Innovation management', 'Community platform', 'Networking',
#        'Commercial Real Estate', 'Consumer service', 'Consumer goods',
#        'MarTech', 'Advertisement', 'Content creation',
#        'Augmented reality', 'Bike Rental', 'Beauty products', 'Tourism',
#        'FemTech', 'Cultural', 'Supply chain platform', 'Social platform',
#        'Real estate', 'AI company', 'Sports startup', 'Matrimony',
#        'Crypto', 'Clothing', 'Analytics', 'IoT platform', 'Commerce',
#        'Defense & Space', 'Business Supplies & Equipment', 'NFT',
#        'Oil & Energy', 'Company-as-a-Service', 'Textiles',
#        'Professional Training & Coaching', 'Maritime',
#        'Housing Marketplace', 'Furniture Rental', 'Telecommunications',
#        'Equity Management', 'Cloud kitchen', 'Nanotechnology',
#        'Community', 'Higher Education',
#        'Mechanical Or Industrial Engineering', 'D2C jewellery',
#        'Sales and Distribution', 'Information Services',
#        'Translation & Localization', 'Investment Banking', 'Femtech',
#        'sports', 'Foootwear', 'Legal Services', 'Veterinary',
#        'Arts & Crafts', 'Investment Management', 'Management Consulting',
#        'B2B startup', 'Design', 'B2B Travel', 'Product studio',
#        'Aviation & Aerospace', 'Staffing & Recruiting'], dtype=object)

# %%
#Extarct wrong sector value 
df[df['Sector'].str.contains('MoEVing is')]
# Out:
#     Company/Brand Founded HeadQuarter  \
# 257       MoEVing    2021    Gurugram
#
#                                                 Sector  \
# 257  MoEVing is India's only Electric Mobility focu...
#
#                     What it does  \
# 257  Vikash Mishra, Mragank Jain
#
#                                            Founders  Investor Amount($) Stage
# 257  Anshuman Maheshwary, Dr Srihari Raju Kalidindi  $5000000      Seed   N/A

# %%
# Lets put the column values in their right position 
m = df['Sector'].str.contains('MoEVing is')
df.loc[m, ['What it does']]= df.loc[m, ['Sector']].to_numpy()

# %%
df['Sector']= df['Sector'].replace({'MoEVing is India\'s only Electric Mobility focused Technology Platform with a vision to accelerate EV adoption in India.':'N/A'}, regex = True)

# %%
df.loc[df['Sector'].str.contains('edtech', case=False, na=False), 'Sector'] = 'Edtech'

# %% [markdown]
# ### Investor Column

# %%
df['Investor'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 2353 entries, 0 to 1208
# Series name: Investor
# Non-Null Count  Dtype
# --------------  -----
# 2353 non-null   object
# dtypes: object(1)
# memory usage: 36.8+ KB

# %%
df[df['Investor'].str.contains('\$')]
# Out:
#            Company/Brand Founded   HeadQuarter           Sector  \
# 242   Fullife Healthcare    2009  Varun Khanna  Pharmaceuticals
# 256   Fullife Healthcare    2009  Varun Khanna  Pharmaceuticals
# 257              MoEVing    2021      Gurugram              N/A
# 545            AdmitKard    2016         Noida           Edtech
# 1100            Sochcast    2020           N/A     Online Media
#
#                                            What it does  \
# 242   Primary Business is Development and Manufactur...
# 256   Primary Business is Development and Manufactur...
# 257   MoEVing is India's only Electric Mobility focu...
# 545   A tech solution for end to end career advisory...
# 1100  Sochcast is an Audio experiences company that ...
#
#                                               Founders      Investor  \
# 242                 Morgan Stanley Private Equity Asia     $22000000
# 256                 Morgan Stanley Private Equity Asia     $22000000
# 257     Anshuman Maheshwary, Dr Srihari Raju Kalidindi      $5000000
# 545   Vamsi Krishna, Pulkit Jain, Gaurav Munjal\t#REF!      $1000000
# 1100           Vinners, Raj Nayak, Amritaanshu Agrawal  $Undisclosed
#
#          Amount($) Stage
# 242       Series C   N/A
# 256       Series C   N/A
# 257           Seed   N/A
# 545   Pre-series A   N/A
# 1100           NaN   N/A

# %%
#moving all the Amounts in the wrong column (Investor) to the appropriate column (Amount($))

i=df['Investor'].str.contains('\$')
df.loc[i, ['Amount($)']]= df.loc[i, ['Investor']].to_numpy()

# %%
df[df['Investor'].str.contains('REF')]
# Out:
#      Company/Brand Founded HeadQuarter                    Sector  \
# 1148     Godamwale    2016      Mumbai  Logistics & Supply Chain
#
#                                            What it does  \
# 1148  Godamwale is tech enabled integrated logistics...
#
#                                        Founders        Investor Amount($)  \
# 1148  Basant Kumar, Vivek Tiwari, Ranbir Nandan  1000000\t#REF!      Seed
#
#      Stage
# 1148   N/A

# %%
#remove foreign attributes seen the 'Investor' column

df['Investor'] =df['Investor'].replace({'\t#REF!':''}, regex = True)

# %%
df[df['Investor'].str.contains('1000')]
# Out:
#      Company/Brand Founded HeadQuarter                    Sector  \
# 545      AdmitKard    2016       Noida                    Edtech
# 1148     Godamwale    2016      Mumbai  Logistics & Supply Chain
#
#                                            What it does  \
# 545   A tech solution for end to end career advisory...
# 1148  Godamwale is tech enabled integrated logistics...
#
#                                               Founders  Investor Amount($)  \
# 545   Vamsi Krishna, Pulkit Jain, Gaurav Munjal\t#REF!  $1000000  $1000000
# 1148         Basant Kumar, Vivek Tiwari, Ranbir Nandan   1000000      Seed
#
#      Stage
# 545    N/A
# 1148   N/A

# %%
i=df['Investor'].str.contains('1000')
df.loc[i, ['Amount($)']]= df.loc[i, ['Investor']].to_numpy()

# %%
df[df['Investor'].str.contains('1000')]
# Out:
#      Company/Brand Founded HeadQuarter                    Sector  \
# 545      AdmitKard    2016       Noida                    Edtech
# 1148     Godamwale    2016      Mumbai  Logistics & Supply Chain
#
#                                            What it does  \
# 545   A tech solution for end to end career advisory...
# 1148  Godamwale is tech enabled integrated logistics...
#
#                                               Founders  Investor Amount($)  \
# 545   Vamsi Krishna, Pulkit Jain, Gaurav Munjal\t#REF!  $1000000  $1000000
# 1148         Basant Kumar, Vivek Tiwari, Ranbir Nandan   1000000   1000000
#
#      Stage
# 545    N/A
# 1148   N/A

# %%
df['Investor'] = df['Investor'].replace({'1000':'N/A'})

# %% [markdown]
# ### Amount Column

# %%
#Replace our nan values with 0

# df['Amount($)'] = df['Amount($)'].replace(np.nan, 0)

# %%
#Inspecting the Amount($) column

df['Amount($)'].unique()
# Out:
# array(['$6,300,000', '$150,000,000', '$28,000,000', '$30,000,000',
#        '$6,000,000', 'Undisclosed', '$1,000,000', '$20,000,000',
#        '$275,000,000', '$22,000,000', '$5,000,000', '$140,500',
#        '$540,000,000', '$15,000,000', '$182,700', '$12,000,000',
#        '$11,000,000', '$15,500,000', '$1,500,000', '$5,500,000',
#        '$2,500,000', '$140,000', '$230,000,000', '$49,400,000',
#        '$32,000,000', '$26,000,000', '$150,000', '$400,000', '$2,000,000',
#        '$100,000,000', '$8,000,000', '$100,000', '$50,000,000',
#        '$120,000,000', '$4,000,000', '$6,800,000', '$36,000,000',
#        '$5,700,000', '$25,000,000', '$600,000', '$70,000,000',
#        '$60,000,000', '$220,000', '$2,800,000', '$2,100,000',
#        '$7,000,000', '$311,000,000', '$4,800,000', '$693,000,000',
#        '$33,000,000', '$200,000', '$340,000', '$45,000,000', '$1,200,000',
#        '$660,000,000', '$120,000', '$7,500,000', '$500,000', '$3,000,000',
#        '$10,000,000', '$145,000,000', nan, '$21,000,000', '$560,000',
#        '$275,000', '$4,500,000', '$390,000,000', '$5,100,000',
#        '$700,000,000', '$2,300,000', '$700,000', '$19,000,000',
#        '$9,000,000', '$40,000,000', '$750,000', '$7,800,000',
#        '$80,000,000', '$1,700,000', '$40,000', '$35,000,000', '$300,000',
#        '$3,500,000', '$200,000,000', '$1,300,000', '$4,100,000',
#        '$575,000', '$800,000', '$18,000,000', '$3,200,000', '$900,000',
#        '$250,000', '$4,700,000', '$75,000,000', '$121,000,000',
#        '$55,000,000', '$3,300,000', '$16,000,000', '$5,400,000',
#        '$4,200,000', '$52,000,000', '$1,100,000', '$118,000,000',
#        '$1,600,000', '$18,500,000', '$70,000,000,000', '$800,000,000',
#        '$400,000,000', '$176,000,000', '$470,000', '$240,000',
#        '$3,000,000,000', '$74,000,000', '$62,000,000', '$500,000,000',
#        '$12,500,000', '$2,200,000,000', '$5,060,000', '$225,000,000',
#        '$24,700,000', '$7,700,000', '$1,90,67,328', '$51,000,000',
#        '$115,000', '$54,000', '$20,000', '$803,146', '$238,000',
#        '$10,220,000', '$1,020,000', '$13,400,000', '$170,000,000',
#        '$2,900,000', '$543,000', '$90,000,000', '$3,400,000',
#        '$23,000,000', '$8,090,000', '$1,030,000', '$5,040,000',
#        '$360,000', '$1,400,000', '$650,000', '$54,000,000', '$42,500,000',
#        '$11,370,000', '$325,000', '$410,000', '$450,000', '$682,000',
#        '$4,050,000', '$1,050,000', '$1,080,000', '$4,300,000',
#        '$2,110,000', '$887,000, $23,000,000', '$764,000', '$603,000',
#        '$409,000', '$292,000', '$286,000', '$136,000',
#        '$800,000,000 to $850,000,000', '$546,000', '$887,000', '$43,000',
#        '$40,900', '$2,200,000', '$5,660,000', '$350,000', '$110,000',
#        '$122,000,000', '$11,635,000', '$1,065,000', '$669,000',
#        '$16,076,000', '$649,600', '$6,700,000', '$266,500', '$2,879,000',
#        '$26,500,000', '$351,000', '$ 8,700,000', '$46,761,000',
#        '$175,000', '9.600,000', '$11,241,000', '$804,000', '$1,340,000',
#        '$467,000', '$133,000', '$3,823,000', '$934,000', '$293,000',
#        '$198,000', '$927,000', '$971,000', '$3,060,000', '$1,862,000',
#        '$232,000', '$2,888,000', '$1,328,000', '$56,000,000',
#        '$2,250,000', '$16,753,000', '$3,700,000', '$1,470,000',
#        '$530,000', '$267,000', '$3,344,000', '$7,200,000', '$2,743,000',
#        '$6,082,000', '$6,609,000', '$27,700,000', '$5,940,000',
#        '$3,964,000', '$197,000', '$4,327,000', '$459,000', '$3,937,000',
#        '$1,313,500', '$229,800', '$5,305,000', '$264,000', '$1,750,000',
#        '$5,967,000', '$2,980,000', 'Undiclsosed', '$323,000',
#        '$1,326,000', '$27,000,000', '$5,200,000', '$2,530,000',
#        '$792,000', '$11,363,000', '$1,715,000', '$329,000', '$5,271,000',
#        '$8,700,000', '$3,226,000', '$5,900,000', '$44,000,000',
#        '$3,879,000', '$13,000,000', '$8,800,000', '$9,500,000',
#        '$920,000', '$35,600,000', '$9,400,000', '$790,000', '$480,000',
#        '$160,000', '$8,200,000', '$4,257,000', '$1,410,000', '$349,800',
#        '$786,000', '$2,004,000', '$123,000,000', '$248,000',
#        '$24,000,000', '$14,259,000', '$24,500,000', '$3,800,000',
#        '$18,370,000', '$68,525,000', '$1,834,000', '$23,850,000',
#        '$43,000,000', '$21,600,000', '$4,598,000', '$13,137,000',
#        '$115,000,000', '$3,900,000', '$670,000', '42.23,000',
#        '$8,500,000', '$3,148,000', '$2,600,000', '25,58,000',
#        '$4,049,500', '$10,500,000', '$6,500,000', '$43,700,000',
#        '$13,800,000', '$306,900', '$420,000', '$627,300', '$113,000,000',
#        '$110,000,000', '$1,397,000', '$448,500', '$7,975,700', '$330,000',
#        '$5,600,000', '$1,402,000', '$21,500,000', '$296,000,000',
#        '$4,900,000', '$1,402,400', '$12,618,300', '$9,900,000',
#        '$982,530', '$70,185,200', '$210,000,000', '$84,000,000',
#        '$39,000,000', '$2,700,000', '$1,403,400', '$105,000,000',
#        '$103,000,000', '$281,300', '$12,700', '$25,000', '$97,500,000',
#        '$507,000', 'Undislosed', '$8,400,000', '$18,300,000',
#        '$125,000,000', '$181,000', '$280,000', '$14,700,000',
#        '$13,200,000', '$8,043,000', '$188,000,000', '$49,000,000',
#        '$160,000,000', '$1,800,000', '$850,000', '$53,000,000',
#        '$7,400,000', '$17,000,000', '$215,000,000', '$350,000,000',
#        '$83,000,000', '$65,000,000', '$150,000,000,000', '$300,000,000',
#        '$140,000,000', '$Undisclosed', '$2000000', '$800000', '$6000000',
#        '$2500000', '$9500000', '$13000000', '$5000000', '$8000000',
#        '$1000000', '$1200000', '$200000', '$12000000', '$1500000',
#        '$1700000', '$5500000', '$400000', '$150000000', '$4000000',
#        '$100000000', '$500000', '$15000000', '$10000000', '$40000000',
#        '$225000000', '$6700000', '$1300000', '$20000000', '$250000',
#        '$21000000', '$52000000', '$3800000', '$17500000', '$42000000',
#        '$2300000', '$7000000', '$30000000', '$450000000', '$28000000',
#        '$300000', '$3500000', '$8500000', '$25000000', '$3000000',
#        '$37000000', '$370000000', '$700000', '$16000000', '$100000',
#        '$44000000', '$770000', '$125000000', '$35000000', '$50000000',
#        '$4900000', '$145000000', '$22000000', '$70000000', '$6600000',
#        '$32000000', '$24000000', '$725000', '$461000', '$96000000',
#        '$60000000', '$500000000', '$266000000', '$4500000', '$325000000',
#        '$6500000', '$1600000', '$225000', '$85000000', '$235000',
#        '$260000', '$2900000', '$53000000', '$1100000', '$150000',
#        '$86000000', '$130000', '$$100,00', '$111000000', '$265000',
#        '$76000000', '$260,000', '$1,000,000,000', '$95,000,000',
#        '$14,300,000', '$81,000,000', '$280,000,000', '$720,000',
#        '$600000', '$9000000', '$1800000', '$330000', '$undisclosed',
#        '$200000000', '$36000000', '$67000000', '$10200000', '$220000000',
#        '$108000000', '$75000000', '$450000', '$660000000', '$45000000',
#        '$3200000', '$370000', '$48000000', '$3600000', '$11000000',
#        '$192000000', '$65000000', '$1400000', '$1900000', '$41000000',
#        '$144000000', '$5200000', '$270000000', '$140000', '$250000000',
#        '$320000', '$350000000', '$4800000', '$38000000', '$125000',
#        '$26000000', '$64000000', '$620000', '$900000', '$2600000',
#        '$1,250,000', '$234,000,000', '$460,000,000', '$13,500,000',
#        '$195,000,000', '$125,000', '$7,300,000', '$16,500,000',
#        '$3300000', '$92000000', '$17000000', '$135000000', '$$1,55,000',
#        '$2100000', '$840000000', '$248000000', '$4300000', '$570000',
#        '$2200000', '$4700000', '$300000000', '$260000000', '$140000000',
#        '$175000000', '$19000000', '$810000', '$7500000', '$600000000',
#        '$90000000', '$5700000', '$6750000', '$78000000', '$5400000',
#        '$115000000', '$255000000', '$18000000', '$570000000', '$550000',
#        '$2700000', '$4200000', '$31000000', '$540000', '$14000000',
#        '$340000', '$', '$6200000', '1000000', '$750000', '$6300000',
#        '$23000000', '$55000000'], dtype=object)

# %%
# This code makes it possible to view all rows in a df
# pd.set_option('display.max_rows', None)

# %%
# Extract rows that do not have the currency sign $ in the amount column
df[-df['Amount($)'].str.contains('\$', na=False)]
# Out:
#                      Company/Brand Founded HeadQuarter  \
# 5                         FlytBase     N/A        Pune
# 6                            Finly     N/A   Bangalore
# 10                      Cub McPaws    2010      Mumbai
# 14                     Open Secret     N/A         N/A
# 19    Azah Personal Care Pvt. Ltd.    2018    Gurugram
# ...                            ...     ...         ...
# 827                        Rezo.ai    2017       Noida
# 833                        Polygon    2017      Mumbai
# 846                       Ingenium    2018   New Delhi
# 853                        Celcius    2020      Mumbai
# 1148                     Godamwale    2016      Mumbai
#
#                         Sector  \
# 5                   Technology
# 6                         SaaS
# 10             E-commerce & AR
# 14                   Food tech
# 19                      Health
# ...                        ...
# 827                 AI startup
# 833                     Crypto
# 846                     Edtech
# 853                  Logistics
# 1148  Logistics & Supply Chain
#
#                                            What it does  \
# 5                           A drone automation platform
# 6     It builds software products that makes work si...
# 10    A B2C  brand that focusses on premium and comf...
# 14             It produces and sells top quality snacks
# 19    Aims to solve some problems in the feminine hy...
# ...                                                 ...
# 827   Conversational AI platform - Innovate the way ...
# 833       Polygon is a blockchain scalability platform.
# 846   Ingenium Education has been pushing e-learning...
# 853   The “ONLINE” Cold Chain network for Reefer tru...
# 1148  Godamwale is tech enabled integrated logistics...
#
#                                            Founders  \
# 5                                       Nitin Gupta
# 6                         Vivek AG, Veekshith C Rai
# 10                          Abhay Bhat, Kinnar Shah
# 14                      Ahana Gautam, Udit Kejriwal
# 19                         Mohammed, Shashwat Diesh
# ...                                             ...
# 827                       Manish Gupta, Rashi Gupta
# 833    Jaynti Kanani, Sandeep Nailwal, Anurag Arjun
# 846   Pramudit Somvanshi, Mohit Patel, Aakash Gupta
# 853        Swarup Bose, Rajneesh Raman, Arbind Jain
# 1148      Basant Kumar, Vivek Tiwari, Ranbir Nandan
#
#                                                Investor    Amount($)  \
# 5                                           Undisclosed  Undisclosed
# 6     Social Capital, AngelList India, Gemba Capital...  Undisclosed
# 10                                    Venture Catalysts  Undisclosed
# 14                                      Matrix Partners  Undisclosed
# 19                            Kunal Bahl, Rohit Bansal.  Undisclosed
# ...                                                 ...          ...
# 827                    Devesh Sachdev, Bhavesh Manglani  Undisclosed
# 833                            Mark Cuban, MiH Ventures  Undisclosed
# 846                                         Lead Angels  Undisclosed
# 853                                 Eaglewings Ventures  Undisclosed
# 1148                                            1000000      1000000
#
#              Stage
# 5              N/A
# 6              N/A
# 10             N/A
# 14             N/A
# 19    Pre series A
# ...            ...
# 827           Seed
# 833            N/A
# 846           Seed
# 853           Seed
# 1148           N/A
#
# [308 rows x 9 columns]

# %%
#replace all values that begin with 'und' in the column with 0- This is to remove all 'undisclosed'
                                           
df.loc[df['Amount($)'].str.contains('und', case=False, na=False), 'Amount($)'] =  0

# %%
# remove $ sign and comma sign

df['Amount($)'] = df['Amount($)'].replace({'\$': '', '\,': '','\!':''}, regex=True)

# %%
df['Amount($)'].unique()
# Out:
# array(['6300000', '150000000', '28000000', '30000000', '6000000', 0,
#        '1000000', '20000000', '275000000', '22000000', '5000000',
#        '140500', '540000000', '15000000', '182700', '12000000',
#        '11000000', '15500000', '1500000', '5500000', '2500000', '140000',
#        '230000000', '49400000', '32000000', '26000000', '150000',
#        '400000', '2000000', '100000000', '8000000', '100000', '50000000',
#        '120000000', '4000000', '6800000', '36000000', '5700000',
#        '25000000', '600000', '70000000', '60000000', '220000', '2800000',
#        '2100000', '7000000', '311000000', '4800000', '693000000',
#        '33000000', '200000', '340000', '45000000', '1200000', '660000000',
#        '120000', '7500000', '500000', '3000000', '10000000', '145000000',
#        nan, '21000000', '560000', '275000', '4500000', '390000000',
#        '5100000', '700000000', '2300000', '700000', '19000000', '9000000',
#        '40000000', '750000', '7800000', '80000000', '1700000', '40000',
#        '35000000', '300000', '3500000', '200000000', '1300000', '4100000',
#        '575000', '800000', '18000000', '3200000', '900000', '250000',
#        '4700000', '75000000', '121000000', '55000000', '3300000',
#        '16000000', '5400000', '4200000', '52000000', '1100000',
#        '118000000', '1600000', '18500000', '70000000000', '800000000',
#        '400000000', '176000000', '470000', '240000', '3000000000',
#        '74000000', '62000000', '500000000', '12500000', '2200000000',
#        '5060000', '225000000', '24700000', '7700000', '19067328',
#        '51000000', '115000', '54000', '20000', '803146', '238000',
#        '10220000', '1020000', '13400000', '170000000', '2900000',
#        '543000', '90000000', '3400000', '23000000', '8090000', '1030000',
#        '5040000', '360000', '1400000', '650000', '54000000', '42500000',
#        '11370000', '325000', '410000', '450000', '682000', '4050000',
#        '1050000', '1080000', '4300000', '2110000', '887000 23000000',
#        '764000', '603000', '409000', '292000', '286000', '136000',
#        '800000000 to 850000000', '546000', '887000', '43000', '40900',
#        '2200000', '5660000', '350000', '110000', '122000000', '11635000',
#        '1065000', '669000', '16076000', '649600', '6700000', '266500',
#        '2879000', '26500000', '351000', ' 8700000', '46761000', '175000',
#        '9.600000', '11241000', '804000', '1340000', '467000', '133000',
#        '3823000', '934000', '293000', '198000', '927000', '971000',
#        '3060000', '1862000', '232000', '2888000', '1328000', '56000000',
#        '2250000', '16753000', '3700000', '1470000', '530000', '267000',
#        '3344000', '7200000', '2743000', '6082000', '6609000', '27700000',
#        '5940000', '3964000', '197000', '4327000', '459000', '3937000',
#        '1313500', '229800', '5305000', '264000', '1750000', '5967000',
#        '2980000', '323000', '1326000', '27000000', '5200000', '2530000',
#        '792000', '11363000', '1715000', '329000', '5271000', '8700000',
#        '3226000', '5900000', '44000000', '3879000', '13000000', '8800000',
#        '9500000', '920000', '35600000', '9400000', '790000', '480000',
#        '160000', '8200000', '4257000', '1410000', '349800', '786000',
#        '2004000', '123000000', '248000', '24000000', '14259000',
#        '24500000', '3800000', '18370000', '68525000', '1834000',
#        '23850000', '43000000', '21600000', '4598000', '13137000',
#        '115000000', '3900000', '670000', '42.23000', '8500000', '3148000',
#        '2600000', '2558000', '4049500', '10500000', '6500000', '43700000',
#        '13800000', '306900', '420000', '627300', '113000000', '110000000',
#        '1397000', '448500', '7975700', '330000', '5600000', '1402000',
#        '21500000', '296000000', '4900000', '1402400', '12618300',
#        '9900000', '982530', '70185200', '210000000', '84000000',
#        '39000000', '2700000', '1403400', '105000000', '103000000',
#        '281300', '12700', '25000', '97500000', '507000', '8400000',
#        '18300000', '125000000', '181000', '280000', '14700000',
#        '13200000', '8043000', '188000000', '49000000', '160000000',
#        '1800000', '850000', '53000000', '7400000', '17000000',
#        '215000000', '350000000', '83000000', '65000000', '150000000000',
#        '300000000', '140000000', '17500000', '42000000', '450000000',
#        '37000000', '370000000', '770000', '6600000', '725000', '461000',
#        '96000000', '266000000', '325000000', '225000', '85000000',
#        '235000', '260000', '86000000', '130000', '10000', '111000000',
#        '265000', '76000000', '1000000000', '95000000', '14300000',
#        '81000000', '280000000', '720000', '67000000', '10200000',
#        '220000000', '108000000', '370000', '48000000', '3600000',
#        '192000000', '1900000', '41000000', '144000000', '270000000',
#        '250000000', '320000', '38000000', '125000', '64000000', '620000',
#        '1250000', '234000000', '460000000', '13500000', '195000000',
#        '7300000', '16500000', '92000000', '135000000', '155000',
#        '840000000', '248000000', '570000', '260000000', '175000000',
#        '810000', '600000000', '6750000', '78000000', '255000000',
#        '570000000', '550000', '31000000', '540000', '14000000', '',
#        '6200000'], dtype=object)

# %%
# we can see seed, series c and pre series A in the values of Amount. Extract those rows
df[df['Amount($)'].str.contains('Series C|Seed|Pre-series A', na=False)]
# Out:
# Empty DataFrame
# Columns: [Company/Brand, Founded, HeadQuarter, Sector, What it does, Founders, Investor, Amount($), Stage]
# Index: []

# %%
#move all stage values from the Amounts ($) column, back to the stage column

n1 = df['Amount($)'].str.contains('Series C|Seed|Pre-series A', na=False)
df.loc[n1, ['Amount($)', 'Stage']] = df.loc[n1, ['Stage', 'Amount($)']].to_numpy()

# %%
#confirming that those foreign values are not in the Amount Column

df[df['Amount($)'].str.contains('Series C|Seed|Pre-series A', na=False)]
# Out:
# Empty DataFrame
# Columns: [Company/Brand, Founded, HeadQuarter, Sector, What it does, Founders, Investor, Amount($), Stage]
# Index: []

# %%
# Lets remove all commas from the column

#df['Amount($)'] = df['Amount($)'].replace({',': ''}, regex=True)

# %%
#When tryimg to turn our column into a float, we got this error "could not convert string to float: '887000 23000000'"
#extract the row with that error 

df[df['Amount($)'].str.contains('887000 23000000', na=False)]
# Out:
#     Company/Brand Founded HeadQuarter   Sector  \
# 465  True Balance    2014    Gurugram  Finance
#
#                                           What it does              Founders  \
# 465  Earn money by meeting financial needs of your ...  Charlie, Jay, Martin
#
#         Investor        Amount($)     Stage
# 465  Balancehero  887000 23000000  Series C

# %%
#Since we cant tell for sure the amount in that row, we will replace it with 0
df['Amount($)'] = df['Amount($)'].replace({'887000 23000000':0 }, regex=True)

# %%
#df = df.astype({'Amount($)':'float'})

#could not convert string to float: '800000000 to 850000000'- Another error encoutered when converting column to string

# %%
# replace the above string with the average of both numbers 

df['Amount($)'] = df['Amount($)'].replace({'800000000 to 850000000':((800000000+850000000)/2)}, regex=True)

# %%
#replacing N/A with 0

df['Amount($)'] = df['Amount($)'].replace({'N/A':0}, regex=True)

# %%
# Rename the Amount($) Column to Amount
df.rename(columns = {'Amount($)':'Amount'}, inplace = True)

# %%
# Extract all strings in the Amount column and convert to float 
df['Amount'] = df['Amount'].str.extract('(\d+)').astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2353 entries, 0 to 1208
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  2353 non-null   object
#  1   Founded        2353 non-null   object
#  2   HeadQuarter    2353 non-null   object
#  3   Sector         2353 non-null   object
#  4   What it does   2353 non-null   object
#  5   Founders       2353 non-null   object
#  6   Investor       2353 non-null   object
#  7   Amount         1949 non-null   float64
#  8   Stage          2352 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 183.8+ KB

# %%
df[df['Amount'].isna()]
# Out:
#                      Company/Brand Founded HeadQuarter                Sector  \
# 5                         FlytBase     N/A        Pune            Technology
# 6                            Finly     N/A   Bangalore                  SaaS
# 10                      Cub McPaws    2010      Mumbai       E-commerce & AR
# 14                     Open Secret     N/A         N/A             Food tech
# 19    Azah Personal Care Pvt. Ltd.    2018    Gurugram                Health
# ...                            ...     ...         ...                   ...
# 1146                           MPL    2018   Bangalore                sports
# 1160         Atomberg Technologies    2012      Mumbai  Consumer Electronics
# 1161               Genext Students    2013      Mumbai                Edtech
# 1166                     OckyPocky    2015    Gurugram                Edtech
# 1193               Sapio Analytics    2019      Mumbai     Computer Software
#
#                                            What it does  \
# 5                           A drone automation platform
# 6     It builds software products that makes work si...
# 10    A B2C  brand that focusses on premium and comf...
# 14             It produces and sells top quality snacks
# 19    Aims to solve some problems in the feminine hy...
# ...                                                 ...
# 1146  Mobile Premier League (MPL), is India’s larges...
# 1160             A maker of energy-efficient smart fans
# 1161  LIVE online classes with expert tutors for K-1...
# 1166  OckyPocky is India's 1st interactive English l...
# 1193  Sapio helps government create policies driven ...
#
#                                                Founders  \
# 5                                           Nitin Gupta
# 6                             Vivek AG, Veekshith C Rai
# 10                              Abhay Bhat, Kinnar Shah
# 14                          Ahana Gautam, Udit Kejriwal
# 19                             Mohammed, Shashwat Diesh
# ...                                                 ...
# 1146              Sai Srinivas Kiran GV, Shubh Malhotra
# 1160                         Manoj Meena, Sibabrata Das
# 1161                    Ali Asgar Kagzi, Piyush Dhanuka
# 1166                                       Amit Agrawal
# 1193  Hardik Somani, Ashwin Srivastava, Shripal Jain...
#
#                                                Investor  Amount         Stage
# 5                                           Undisclosed     NaN           N/A
# 6     Social Capital, AngelList India, Gemba Capital...     NaN           N/A
# 10                                    Venture Catalysts     NaN           N/A
# 14                                      Matrix Partners     NaN           N/A
# 19                            Kunal Bahl, Rohit Bansal.     NaN  Pre series A
# ...                                                 ...     ...           ...
# 1146                                    Legatum Capital     NaN      Series E
# 1160                                     Ka Enterprises     NaN           N/A
# 1161                                  Navneet Education     NaN           N/A
# 1166              Sujeet Kumar, SucSEED Indovation Fund     NaN          Seed
# 1193                        Rachit Poddar, Rajesh Gupta     NaN           N/A
#
# [404 rows x 9 columns]

# %%
#replace all the 0 with the mean 
df['Amount'].replace(to_replace=0, value = df['Amount'].mean(), inplace = True)

# %%
#replace the nan values with mean 
df.fillna(df.mean(), inplace=True)
# Out:
# C:\Users\GilB\AppData\Local\Temp\ipykernel_15308\3815401649.py:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.fillna(df.mean(), inplace=True)

# %%
df[df['Amount'].isna()]
# Out:
# Empty DataFrame
# Columns: [Company/Brand, Founded, HeadQuarter, Sector, What it does, Founders, Investor, Amount, Stage]
# Index: []

# %% [markdown]
# # Answering the questions.

# %% [markdown]
# ### 1. Which company received the highest amount of funds?

# %%
df.sort_values(['Amount'], ascending = False, inplace=True)
df.head(20)
# Out:
#                      Company/Brand Founded HeadQuarter  \
# 73                 Alteria Capital    2018      Mumbai
# 280   Reliance Retail Ventures Ltd    2006      Mumbai
# 317                      Snowflake    2012  California
# 328                       Reliance    1973      Mumbai
# 346               VerSe Innovation    2007   Bangalore
# 935                   Dream Sports    2008      Mumbai
# 302       Reliance Retail Ventures    2006      Mumbai
# 53                          Swiggy    2014   Bangalore
# 50                         PhonePe    2015   New Delhi
# 85                             Oyo    2013    Gurugram
# 15                          Zomato    2008     Gurgaon
# 532                            OYO    2013    Gurugram
# 983                        Zetwerk    2018   Bangalore
# 1070                        Meesho    2015   Bangalore
# 16                          Byju's    2011         N/A
# 326                         Byju’s    2011   Bangalore
# 70                       ShareChat    2015   Bangalore
# 362                         Byju’s    2011   Bangalore
# 267                            Ola    2010   Bangalore
# 736                         BYJU'S    2011   Bangalore
#
#                                     Sector  \
# 73                                 FinTech
# 280                                 Retail
# 317                           Tech company
# 328     Multinational conglomerate company
# 346                  Innovation Management
# 935                                 Sports
# 302                             E-commerce
# 53                           Food delivery
# 50                                 FinTech
# 85                             Hospitality
# 15                           Food Delivery
# 532                            Hospitality
# 983   Mechanical Or Industrial Engineering
# 1070                       Social commerce
# 16                                  Edtech
# 326                                 Edtech
# 70                            Social Media
# 362                                 Edtech
# 267                               Mobility
# 736                                 Edtech
#
#                                            What it does  \
# 73             Alteria Capital is a Venture debt firm .
# 280   Reliance Retail offers online shopping and a c...
# 317   Snowflake is a cloud data platform that provid...
# 328   Reliance owns businesses across India engaged ...
# 346                    Owner of Dailyhunt App and I-Pay
# 935   Dream Sports is India’s leading sports technol...
# 302   Reliance Retail offers online shopping and a c...
# 53    Swiggy is an on-demand food delivery platform ...
# 50    PhonePe is a mobile payments application that ...
# 85                  Provides rooms for comfortable stay
# 15    Zomato is a food delivery and restaurant disco...
# 532   OYO is a global platform that empowers entrepr...
# 983   ZETWERK is a universal manufacturing network p...
# 1070  Meesho is India’s largest marketplace for long...
# 16                     Provides online learning classes
# 326   An Indian educational technology and online tu...
# 70    ShareChat is a social networking and regional ...
# 362   An Indian educational technology and online tu...
# 267   Ola is India’s largest mobility platform and o...
# 736   BYJU'S is an educational technology company th...
#
#                                                Founders  \
# 73                                         Vinod Murali
# 280                                       Mukesh Ambani
# 317   Benoit Dageville, Bob Muglia, Marcin Zukowski,...
# 328                                    Dhirubhai Ambani
# 346                                      Virendra Gupta
# 935                                          Harsh Jain
# 302                                       Mukesh Ambani
# 53        Nandan Reddy, Rahul Jaimini, Sriharsha Majety
# 50           Burzin Engineer, Rahul Chari, Sameer Nigam
# 85                                       Ritesh Agarwal
# 15        Deepinder Goyal, Gaurav Gupta, Pankaj Chaddah
# 532                                      Ritesh Agarwal
# 983                                       Amrit Acharya
# 1070                      Sanjeev Barnwal, Vidit Aatrey
# 16                                      Byju Raveendran
# 326                                     Byju Raveendran
# 70     Ankush Sachdeva, Bhanu Pratap Singh, Farid Ahsan
# 362                                     Byju Raveendran
# 267                                    Bhavish Aggarwal
# 736                    Byju Raveendran, Divya Gokulnath
#
#                                                Investor          Amount  \
# 73                                                  N/A 150000000000.00
# 280            Silver Lake, Mubadala Investment Company  70000000000.00
# 317     Salesforce Ventures, Dragoneer Investment Group   3000000000.00
# 328                  Facebook, Google, KKR, Silver Lake   2200000000.00
# 346   Canaan Valley Capital, Glade Brook Capital Par...   1000000000.00
# 935   Falcon Edge, DST Global, D1 Capital, Redbird C...    840000000.00
# 302           General Atlantic, Kohlberg Kravis Roberts    800000000.00
# 53                       Carmignac, Falcon Edge Capital    800000000.00
# 50                                             Flipkart    700000000.00
# 85    MyPreferred Transformation, Avendus Finance, S...    693000000.00
# 15                        Kora, Tiger Global Management    660000000.00
# 532       SoftBank Vision Fund, Hindustan Media Venture    660000000.00
# 983                                           TradeCred    600000000.00
# 1070                                Fidelity, B Capital    570000000.00
# 16    South Africa’s Naspers Ventures, the CPP Inves...    540000000.00
# 326               Owl Ventures, Tiger Global Management    500000000.00
# 70                       Twitter Ventures, Pawan Munjal    500000000.00
# 362               Owl Ventures, Tiger Global Management    500000000.00
# 267       Marquee international institutional investors    500000000.00
# 736                             BlackRock, Owl Ventures    460000000.00
#
#          Stage
# 73        Debt
# 280        N/A
# 317        N/A
# 328        N/A
# 346   Series H
# 935        N/A
# 302        N/A
# 53         N/A
# 50         N/A
# 85         N/A
# 15         N/A
# 532        N/A
# 983        N/A
# 1070       N/A
# 16         N/A
# 326        N/A
# 70         N/A
# 362        N/A
# 267        N/A
# 736   Series F

# %%
Company = df['Company/Brand'].head(10)
Amount = df['Amount'].head(10)


plt.xlabel('Amount of Funding Received')
plt.ylabel('Company')
plt.title('Top 10 companies in funding')
plt.barh(Company, Amount, color='blue')
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# ####  Alteria Capital received the highest funds  of $150,000,000,000.00

# %% [markdown]
# ### 2. Which Company received the lowest amount of funds

# %%
df.sort_values(['Amount'], ascending = False, inplace=True)
df.tail(5)
# Out:
#            Company/Brand Founded HeadQuarter      Sector  \
# 1000             Medicus     N/A      Mumbai  Healthtech
# 1002            Teach Us     N/A         N/A      Edtech
# 308                 Glii    2020       Noida      Dating
# 834           Peel Works    2010      Mumbai        SaaS
# 552   SATYA Microcapital    1995       Delhi     Fintech
#
#                                            What it does  \
# 1000  AI-based platform that explains and interprets...
# 1002  Educational portal which enables the students ...
# 308     India’s finest dating companionship application
# 834                E-commerce for corner/retail stores.
# 552   Microfinance company that offers collateral-fr...
#
#                                 Founders                     Investor  \
# 1000            Bhavesh Shah, Manav Shah              Angel investors
# 1002                                 N/A              Angel investors
# 308                       Shivam Kaushik            We Founder Circle
# 834   Sachin Chhabra, Nidhi Ramachandran                CESC Ventures
# 552                         Vivek Tiwari  BlueOrchard Finance Limited
#
#        Amount        Stage
# 1000 12700.00          N/A
# 1002 12700.00   Seed Round
# 308  10000.00         Seed
# 834     42.00  Series C, D
# 552      9.00          N/A

# %%
Company = df['Company/Brand'].tail(10)
Amount = df['Amount'].tail(10)


plt.xlabel('Amount of Funding Received')
plt.ylabel('Company')
plt.title('Bottom 10 companies in funding')
plt.barh(Company, Amount, color='blue')
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# #### SATYA Microcapital Received the lowest funds of  $9.00

# %% [markdown]
# ### 3. Which Industry received the highest amount of funding?

# %%
#Group the funds received by sector and sort it out from highest to lowest

df3 = df.groupby(['Sector'])['Amount'].sum().reset_index()
df3.sort_values(['Amount'], ascending = False, inplace=True)
df3
# Out:
#                Sector          Amount
# 204           FinTech 156795709876.32
# 393            Retail  70645166660.78
# 176            Edtech  11990320804.20
# 164        E-commerce   3721851964.66
# 446      Tech company   3303633321.55
# ..                ...             ...
# 338      Milk startup       100000.00
# 304        Legal tech       100000.00
# 286  Interior & decor       100000.00
# 359      Oil & Energy       100000.00
# 487         Warehouse        54000.00
#
# [495 rows x 2 columns]

# %%
Industry = df3['Sector'].head(15)
Amount = df3['Amount'].head(15)


plt.xlabel('Amount')
plt.ylabel('Industry')
plt.title('Highest funded Industries')
plt.barh(Industry, Amount, color='Orange')
# Out:
# <BarContainer object of 15 artists>

# %% [markdown]
# #### FinTech received the highest amount of fund

# %% [markdown]
# ### 4. Which industry received the lowest amount of funding?

# %%
df4 = df.groupby(['Sector'])['Amount'].sum().reset_index()
df4.sort_values(['Amount'], ascending = True, inplace=True)
df4
# Out:
#                Sector          Amount
# 487         Warehouse        54000.00
# 338      Milk startup       100000.00
# 163          E-Sports       100000.00
# 304        Legal tech       100000.00
# 286  Interior & decor       100000.00
# ..                ...             ...
# 446      Tech company   3303633321.55
# 164        E-commerce   3721851964.66
# 176            Edtech  11990320804.20
# 393            Retail  70645166660.78
# 204           FinTech 156795709876.32
#
# [495 rows x 2 columns]

# %%
Industry = df4['Sector'].head(15)
Amount = df4['Amount'].head(15)


plt.xlabel('Amount')
plt.ylabel('Industry')
plt.title('Lowest funded Industries')
plt.barh(Industry, Amount, color='Orange')
# Out:
# <BarContainer object of 15 artists>

# %% [markdown]
# #### Warehouse received the lowest funding

# %% [markdown]
# ### 5. Is there a correlation between company age and funds received?

# %%
df['Founded'].mode()
# Out:
# 0    2019
# Name: Founded, dtype: object

# %%
#Replacing all N/A values in Founded with the mode
df['Founded'] = df['Founded'].replace({'N/A':'2019'}, regex=True).astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2353 entries, 73 to 552
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  2353 non-null   object
#  1   Founded        2353 non-null   int32
#  2   HeadQuarter    2353 non-null   object
#  3   Sector         2353 non-null   object
#  4   What it does   2353 non-null   object
#  5   Founders       2353 non-null   object
#  6   Investor       2353 non-null   object
#  7   Amount         2353 non-null   float64
#  8   Stage          2352 non-null   object
# dtypes: float64(1), int32(1), object(7)
# memory usage: 174.6+ KB

# %%
# Creating new coulmn Company_age
df['Company_Age'] = 2023 - df['Founded']

# %%
#Sorting out the data by Company Age
df.sort_values(['Company_Age'], ascending = False, inplace=True)
df
# Out:
#          Company/Brand  Founded HeadQuarter  \
# 1001          Duroflex     1963   Bangalore
# 328           Reliance     1973      Mumbai
# 456   Biocon Biologics     1978   Bangalore
# 152             Biocon     1978   Bangalore
# 30                Arya     1982       Noida
# ...                ...      ...         ...
# 895         ElectricPe     2021   Bangalore
# 1197             Fleek     2021   Bangalore
# 1023         Sourcewiz     2021    Gurugram
# 229           Trinkerr     2021   Bangalore
# 490            G.O.A.T     2021   Bangalore
#
#                                   Sector  \
# 1001                           Furniture
# 328   Multinational conglomerate company
# 456                        BioTechnology
# 152                           Healthcare
# 30                              AgriTech
# ...                                  ...
# 895                                   EV
# 1197                            Internet
# 1023   Information Technology & Services
# 229                      Capital Markets
# 490                                  D2C
#
#                                            What it does  \
# 1001  5 decades of experience, superior quality and ...
# 328   Reliance owns businesses across India engaged ...
# 456   Biocon is a fully integrated pure play biosimi...
# 152   Biocon is a healthcare and technology, company...
# 30    "Simplifying Agribusiness" Throughout Agri-Sup...
# ...                                                 ...
# 895   India's largest Electric Vehicle Charging Plat...
# 1197  Fleek helps track & manage subscriptions in on...
# 1023  Building a platform for exporters to digitize ...
# 229   Trinkerr is India's first social trading platf...
# 490   G.O.A.T Brand Labs provides a tech-enabled pla...
#
#                                                Founders  \
# 1001                                       P. C. Mathew
# 328                                    Dhirubhai Ambani
# 456                                 Kiran Mazumdar-Shaw
# 152                                 Kiran Mazumdar-Shaw
# 30    Chattanathan Devarajan, Prasanna Rao, Anand Ch...
# ...                                                 ...
# 895                       Avinash Sharma, Raghav Rohila
# 1197                 Aditya Uttaravalli, Arvind Eashwar
# 1023                    Divyaanshu Makkar, Vikas, Mayur
# 229                     Manvendra Singh, Gaurav Agarwal
# 490                       Rishi Vasudev, Rameswar Misra
#
#                                 Investor        Amount     Stage  Company_Age
# 1001            Norwest Venture Partners   60000000.00       N/A           60
# 328   Facebook, Google, KKR, Silver Lake 2200000000.00       N/A           50
# 456          Goldman Sachs, Tata Capital   70000000.00       N/A           45
# 152                        Goldman Sachs   15000000.00       N/A           45
# 30                         Quona Capital   21000000.00  Series B           41
# ...                                  ...           ...       ...          ...
# 895         Blume Ventures, Micelio Fund    3000000.00      Seed            2
# 1197                              Axilor    1000000.00      Seed            2
# 1023        Blume, Alpha Wave Incubation    3000000.00      Seed            2
# 229                          Accel India    6600000.00  Series A            2
# 490      Tiger Global, Flipkart Ventures   36000000.00  Series A            2
#
# [2353 rows x 10 columns]

# %%
df['Company_Age']
# Out:
# 1001    60
# 328     50
# 456     45
# 152     45
# 30      41
#         ..
# 895      2
# 1197     2
# 1023     2
# 229      2
# 490      2
# Name: Company_Age, Length: 2353, dtype: int32

# %%
#Plotting a scatter plot of Company age by Funds received 
Age = df['Company_Age']
Amount = df['Amount']





plt.xlabel('Age')
plt.ylabel('Amount')
plt.title('Relationship Between Age and Funding')
plt.scatter(Age, Amount, color='red', alpha=0.5, s=100)
plt.show()

# %% [markdown]
# #### There is no correlation between age and funds received

# %% [markdown]
# ### 6. Which location recorded the highest amount of funding received?

# %%
df.sort_values(['Amount'], ascending = False, inplace=True)
df.head(20)
# Out:
#                      Company/Brand  Founded HeadQuarter  \
# 73                 Alteria Capital     2018      Mumbai
# 280   Reliance Retail Ventures Ltd     2006      Mumbai
# 317                      Snowflake     2012  California
# 328                       Reliance     1973      Mumbai
# 346               VerSe Innovation     2007   Bangalore
# 935                   Dream Sports     2008      Mumbai
# 53                          Swiggy     2014   Bangalore
# 302       Reliance Retail Ventures     2006      Mumbai
# 50                         PhonePe     2015   New Delhi
# 85                             Oyo     2013    Gurugram
# 15                          Zomato     2008     Gurgaon
# 532                            OYO     2013    Gurugram
# 983                        Zetwerk     2018   Bangalore
# 1070                        Meesho     2015   Bangalore
# 16                          Byju's     2011         N/A
# 362                         Byju’s     2011   Bangalore
# 326                         Byju’s     2011   Bangalore
# 70                       ShareChat     2015   Bangalore
# 267                            Ola     2010   Bangalore
# 736                         BYJU'S     2011   Bangalore
#
#                                     Sector  \
# 73                                 FinTech
# 280                                 Retail
# 317                           Tech company
# 328     Multinational conglomerate company
# 346                  Innovation Management
# 935                                 Sports
# 53                           Food delivery
# 302                             E-commerce
# 50                                 FinTech
# 85                             Hospitality
# 15                           Food Delivery
# 532                            Hospitality
# 983   Mechanical Or Industrial Engineering
# 1070                       Social commerce
# 16                                  Edtech
# 362                                 Edtech
# 326                                 Edtech
# 70                            Social Media
# 267                               Mobility
# 736                                 Edtech
#
#                                            What it does  \
# 73             Alteria Capital is a Venture debt firm .
# 280   Reliance Retail offers online shopping and a c...
# 317   Snowflake is a cloud data platform that provid...
# 328   Reliance owns businesses across India engaged ...
# 346                    Owner of Dailyhunt App and I-Pay
# 935   Dream Sports is India’s leading sports technol...
# 53    Swiggy is an on-demand food delivery platform ...
# 302   Reliance Retail offers online shopping and a c...
# 50    PhonePe is a mobile payments application that ...
# 85                  Provides rooms for comfortable stay
# 15    Zomato is a food delivery and restaurant disco...
# 532   OYO is a global platform that empowers entrepr...
# 983   ZETWERK is a universal manufacturing network p...
# 1070  Meesho is India’s largest marketplace for long...
# 16                     Provides online learning classes
# 362   An Indian educational technology and online tu...
# 326   An Indian educational technology and online tu...
# 70    ShareChat is a social networking and regional ...
# 267   Ola is India’s largest mobility platform and o...
# 736   BYJU'S is an educational technology company th...
#
#                                                Founders  \
# 73                                         Vinod Murali
# 280                                       Mukesh Ambani
# 317   Benoit Dageville, Bob Muglia, Marcin Zukowski,...
# 328                                    Dhirubhai Ambani
# 346                                      Virendra Gupta
# 935                                          Harsh Jain
# 53        Nandan Reddy, Rahul Jaimini, Sriharsha Majety
# 302                                       Mukesh Ambani
# 50           Burzin Engineer, Rahul Chari, Sameer Nigam
# 85                                       Ritesh Agarwal
# 15        Deepinder Goyal, Gaurav Gupta, Pankaj Chaddah
# 532                                      Ritesh Agarwal
# 983                                       Amrit Acharya
# 1070                      Sanjeev Barnwal, Vidit Aatrey
# 16                                      Byju Raveendran
# 362                                     Byju Raveendran
# 326                                     Byju Raveendran
# 70     Ankush Sachdeva, Bhanu Pratap Singh, Farid Ahsan
# 267                                    Bhavish Aggarwal
# 736                    Byju Raveendran, Divya Gokulnath
#
#                                                Investor          Amount  \
# 73                                                  N/A 150000000000.00
# 280            Silver Lake, Mubadala Investment Company  70000000000.00
# 317     Salesforce Ventures, Dragoneer Investment Group   3000000000.00
# 328                  Facebook, Google, KKR, Silver Lake   2200000000.00
# 346   Canaan Valley Capital, Glade Brook Capital Par...   1000000000.00
# 935   Falcon Edge, DST Global, D1 Capital, Redbird C...    840000000.00
# 53                       Carmignac, Falcon Edge Capital    800000000.00
# 302           General Atlantic, Kohlberg Kravis Roberts    800000000.00
# 50                                             Flipkart    700000000.00
# 85    MyPreferred Transformation, Avendus Finance, S...    693000000.00
# 15                        Kora, Tiger Global Management    660000000.00
# 532       SoftBank Vision Fund, Hindustan Media Venture    660000000.00
# 983                                           TradeCred    600000000.00
# 1070                                Fidelity, B Capital    570000000.00
# 16    South Africa’s Naspers Ventures, the CPP Inves...    540000000.00
# 362               Owl Ventures, Tiger Global Management    500000000.00
# 326               Owl Ventures, Tiger Global Management    500000000.00
# 70                       Twitter Ventures, Pawan Munjal    500000000.00
# 267       Marquee international institutional investors    500000000.00
# 736                             BlackRock, Owl Ventures    460000000.00
#
#          Stage  Company_Age
# 73        Debt            5
# 280        N/A           17
# 317        N/A           11
# 328        N/A           50
# 346   Series H           16
# 935        N/A           15
# 53         N/A            9
# 302        N/A           17
# 50         N/A            8
# 85         N/A           10
# 15         N/A           15
# 532        N/A           10
# 983        N/A            5
# 1070       N/A            8
# 16         N/A           12
# 362        N/A           12
# 326        N/A           12
# 70         N/A            8
# 267        N/A           13
# 736   Series F           12

# %%
Location = df['HeadQuarter'].head(20)
Amount = df['Amount'].head(20)





plt.xlabel('Amount')
plt.ylabel('Location')
plt.title('Locations with the most funding')
plt.barh(Location, Amount, color='maroon')
plt.show()

# %% [markdown]
# Collective companies in a location

# %%
df2 = df.groupby(['HeadQuarter'])['Amount'].sum().reset_index()

# %%
df2.sort_values(['Amount'], ascending = False, inplace=True)
df2.head()
# Out:
#    HeadQuarter          Amount
# 60      Mumbai 238411032474.86
# 5    Bangalore  39066583651.28
# 34    Gurugram   9799231323.32
# 63   New Delhi   7313518484.10
# 61         N/A   5155303176.32

# %%
Location = df2['HeadQuarter'].head()
Amount = df2['Amount'].head()





plt.xlabel('Amount')
plt.ylabel('Location')
plt.title('Locations with the most funding (Collective)')
plt.barh(Location, Amount, color='maroon')
plt.show()

# %% [markdown]
# #### Startups in Mumbai had the collective highest amount of funds received

# %% [markdown]
# ### 7. What is the average age of the start-ups?

# %%
A1 = df['Company_Age'].mean()

print(f'The Average age of the startups is {A1:.2f} years old')
# Out:
# The Average age of the startups is 6.62 years old

# %% [markdown]
# ### 8. What is the average amount of funding received?

# %%
B1= df['Amount'].mean()

print(f'The Average Amount of fundingreceived the startups is ${B1:.2f}')
# Out:
# The Average Amount of fundingreceived the startups is $140466660.78

# %% [markdown]
# ### 9. How many companies were funded in each year?

# %%
C1= df2018['Amount'].notnull().sum()

print(f'{C1} companies were funded in 2018')
# Out:
# 526 companies were funded in 2018

# %%
D1= df2019['Amount($)'].notnull().sum()

print(f'{D1} companies were funded in 2019')
# Out:
# 89 companies were funded in 2019

# %%
E1 = df2020['Amount($)'].notnull().sum()

print(f'{E1} companies were funded in 2020')
# Out:
# 1052 companies were funded in 2020

# %%
F1 = df2021['Amount($)'].notnull().sum()

print(f'{F1} companies were funded in 2021')
# Out:
# 1206 companies were funded in 2021

# %% [markdown]
# # Hypothesis

# %% [markdown]
# Null Hypothesis - The sector of a start-up affect the amount of funding received.
#
# Alternate Hypothesis - The sector of a start up does not affect the amount of funding received

# %% [markdown]
# Based on our analysis, we accept the Null Hypothesis
